# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install pytorch-lightning -q -U

# %%
# Preprocess the Penn Treebank dataset
# Load the dataset
import torch

def read_data(file_path):
    parsed_data = []
    with open(file_path, 'r', encoding='utf-8') as f:
      parsed_tokens = []
      for line in f:
            if line == '\n' or line[0] == '#':
                if parsed_tokens:
                  parsed_data.append(parsed_tokens)
                parsed_tokens = []
            else:
                parts = line.strip().split(' _ _ ')
                word = parts[0]
                tag = parts[1] if len(parts) > 1 else ''
                parsed_tokens.append((word, tag))
    return parsed_data

train_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/HI-Hindi/hi_train.conll')
dev_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/HI-Hindi/hi_dev.conll')
test_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/HI-Hindi/hi_test.conll')

for i in range(100):
    print(train_dataset[i])
# Out:
# [('यह', 'O'), ('झियान', 'B-HumanSettlement'), ('चीन', 'B-HumanSettlement'), ('के', 'O'), ('केंद्र', 'O'), ('भाग', 'O'), ('में', 'O'), ('स्थित', 'O'), ('है।', 'O')]
# [('२००३', 'O'), ('में', 'O'), ('विंबलडन,', 'B-HumanSettlement'), ('लंदन', 'I-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('साइकिल', 'O'), ('चालक', 'O'), ('के', 'O'), ('साथ', 'O'), ('टकराव', 'O'), ('के', 'O'), ('दौरान', 'O'), ('रोड्स', 'O'), ('को', 'O'), ('मार', 'O'), ('दिया', 'O'), ('गया', 'O'), ('था।', 'O')]
# [('उन्होंने', 'O'), ('अल्जियर्स', 'B-HumanSettlement'), ('में', 'O'), ('राजनीति', 'O'), ('विज्ञान', 'O'), ('का', 'O'), ('अध्ययन', 'O'), ('किया।', 'O')]
# [('चार्ल्स', 'O'), ('कोर्डोबा', 'B-HumanSettlement'), ('अमीरात', 'I-HumanSettlement'), ('के', 'O'), ('साथ', 'O'), ('कूटनीति', 'O'), ('में', 'O'), ('लगे', 'O'), ('हुए', 'O'), ('८६५', 'O'), ('में', 'O'), ('मुहम्मद', 'B-Politician'), ('प्रथम', 'I-Politician'), ('कोर्डोबा', 'I-Politician'), ('से', 'O'), ('ऊंट', 'O'), ('प्राप्त', 'O'), ('करते', 'O'), ('हैं।', 'O')]
# [('वह', 'O'), ('२०००', 'O'), ('के', 'O'), ('आसपास', 'O'), ('बर्लिन,', 'B-HumanSettlement'), ('जर्मनी', 'I-HumanSettlement'), ('में', 'O'), ('चली', 'O'), ('गई।', 'O')]
# [('यह', 'O'), ('१९०४', 'O'), ('में', 'O'), ('फीफा', 'B-ORG'), ('का', 'O'), ('संस्थापक', 'O'), ('सदस्य', 'O'), ('था', 'O'), ('और', 'O'), ('१९५४', 'O'), ('में', 'O'), ('यूरोपीय', 'B-ORG'), ('फुटबॉल', 'I-ORG'), ('महासंघ', 'I-ORG'), ('और', 'O'), ('ब्रुसेल्स', 'B-HumanSettlement'), ('में', 'O'), ('स्थित', 'O'), ('था', 'O'), ('हेसल', 'B-OtherLOC'), ('स्टेडियम', 'I-OtherLOC'), ('से', 'O'), ('दूर', 'O'), ('नहीं।', 'O')]
# [('किताबें', 'O'), ('बोस्टन', 'B-HumanSettlement'), ('में', 'O'), ('सेट', 'O'), ('की', 'O'), ('गई', 'O'), ('हैं।', 'O')]
# [('ऐलिस', 'O'), ('जेम्स', 'B-Politician'), ('४', 'I-Politician'), ('फ़्रांस', 'B-HumanSettlement'), ('के', 'O'), ('साथ', 'O'), ('गठबंधन', 'O'), ('के', 'O'), ('बारे', 'O'), ('में', 'O'), ('अधिक', 'O'), ('जानने', 'O'), ('के', 'O'), ('लिए', 'O'), ('स्टर्लिंग', 'B-Facility'), ('किला', 'I-Facility'), ('का', 'O'), ('दौरा', 'O'), ('करता', 'O'), ('है।', 'O')]
# [('मनोहर', 'B-Artist'), ('श्याम', 'I-Artist'), ('जोशी', 'I-Artist'), ('(', 'O'), ('१९३३', 'O'), ('-', 'O'), ('२००६', 'O'), (')', 'O'), ('लेखक', 'O'), (';', 'O'), ('अल्', 'B-HumanSettlement'), ('मोड़ा', 'I-HumanSettlement'), ('में', 'O'), ('जन्मे।', 'O')]
# [('यह', 'O'), ('केवल', 'O'), ('ब्राज़ील', 'B-HumanSettlement'), ('में', 'O'), ('पाया', 'O'), ('जाता', 'O'), ('है।', 'O')]
# [('पांच', 'O'), ('अन्य', 'O'), ('गुरिल्ला', 'O'), ('सुनसान', 'O'), ('हो', 'O'), ('गए', 'O'), ('और', 'O'), ('चिली', 'B-HumanSettlement'), ('में', 'O'), ('भाग', 'O'), ('गए।', 'O')]
# [('१९३६', 'O'), ('में', 'O'), ('उन्होंने', 'O'), ('इंग्लैण्ड', 'B-HumanSettlement'), ('पर', 'O'), ('स्थानांतरित', 'O'), ('कर', 'O'), ('दिया।', 'O')]
# [('एयरोस्टन', 'O'), ('एक', 'O'), ('कार्गो', 'O'), ('एयरलाइन', 'O'), ('है', 'O'), ('जो', 'O'), ('मानस', 'B-Station'), ('अन्तर्राष्ट्रीय', 'I-Station'), ('विमानक्षेत्र', 'I-Station'), ('किर्गिज़स्तान', 'B-HumanSettlement'), ('में', 'O'), ('स्थित', 'O'), ('है', 'O'), ('जो', 'O'), ('२००४', 'O'), ('से', 'O'), ('२०१२', 'O'), ('तक', 'O'), ('और', 'O'), ('फिर', 'O'), ('२०२०', 'O'), ('से', 'O'), ('उड़ान', 'O'), ('भरी।', 'O')]
# [('यह', 'O'), ('सूरीनाम', 'B-HumanSettlement'), ('बोलिविया', 'B-HumanSettlement'), ('पैराग्वे', 'B-HumanSettlement'), ('और', 'O'), ('ब्राज़ील', 'B-HumanSettlement'), ('में', 'O'), ('पाया', 'O'), ('जाता', 'O'), ('है।', 'O')]
# [('ज़ैंड', 'O'), ('ने', 'O'), ('अपनी', 'O'), ('प्राथमिक', 'O'), ('शिक्षा', 'O'), ('तेहरान', 'B-HumanSettlement'), ('में', 'O'), ('प्राप्त', 'O'), ('की', 'O'), ('और', 'O'), ('अपनी', 'O'), ('शिक्षा', 'O'), ('जारी', 'O'), ('रखने', 'O'), ('के', 'O'), ('लिए', 'O'), ('रूस', 'B-HumanSettlement'), ('पर', 'O'), ('गए।', 'O')]
# [('१९५८', 'O'), ('में', 'O'), ('उनकी', 'O'), ('पत्नी', 'O'), ('की', 'O'), ('मृत्यु', 'O'), ('के', 'O'), ('बाद', 'O'), ('उनके', 'O'), ('परिवार', 'O'), ('ने', 'O'), ('उन्हें', 'O'), ('हंटिंगटन', 'B-HumanSettlement'), ('पर', 'O'), ('लौटाया', 'O'), ('जहां', 'O'), ('उनकी', 'O'), ('बहनों', 'O'), ('और', 'O'), ('मां', 'O'), ('ने', 'O'), ('उनकी', 'O'), ('परवाह', 'O'), ('की।', 'O')]
# [('नगरपालिका', 'O'), ('चुनावों', 'O'), ('के', 'O'), ('लिए', 'O'), ('चेकोस्लोवेकिया', 'B-HumanSettlement'), ('में', 'O'), ('पुरुषों', 'O'), ('और', 'O'), ('महिलाओं', 'O'), ('के', 'O'), ('लिए', 'O'), ('समान', 'O'), ('मताधिकार', 'O'), ('लागू', 'O'), ('किया', 'O'), ('गया', 'O'), ('था।', 'O')]
# [('रॉबर्ट्स', 'O'), ('का', 'O'), ('जन्म', 'O'), ('लुसाका', 'B-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था', 'O'), ('और', 'O'), ('ज़िम्बाब्वे', 'B-HumanSettlement'), ('में', 'O'), ('शिक्षित', 'O'), ('किया', 'O'), ('गया', 'O'), ('था।', 'O')]
# [('श्रीलंका', 'B-HumanSettlement'), ('में', 'O'), ('एबोनी', 'O'), ('एक', 'O'), ('संरक्षित', 'O'), ('प्रजाति', 'O'), ('है', 'O'), ('और', 'O'), ('कटाई', 'O'), ('और', 'O'), ('आबनूस', 'O'), ('की', 'O'), ('बिक्री', 'O'), ('कारावास', 'O'), ('से', 'O'), ('अवैध', 'O'), ('और', 'O'), ('दंडनीय', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('साम्राज्य', 'B-HumanSettlement'), ('की', 'O'), ('एक', 'O'), ('नेविगेशनल', 'O'), ('सूची', 'O'), ('है।', 'O')]
# [('१९४९', 'O'), ('में', 'O'), ('एक', 'O'), ('ताइपे', 'B-HumanSettlement'), ('संस्करण', 'O'), ('की', 'O'), ('स्थापना', 'O'), ('की', 'O'), ('गई', 'O'), ('थी।', 'O')]
# [('वह', 'O'), ('कोलोराडो', 'B-HumanSettlement'), ('स्प्रिंग्स', 'I-HumanSettlement'), ('में', 'O'), ('चले', 'O'), ('गए', 'O'), ('और', 'O'), ('व्यवसाय', 'O'), ('और', 'O'), ('रियल', 'O'), ('एस्टेट', 'O'), ('कानून', 'O'), ('पर', 'O'), ('ध्यान', 'O'), ('केंद्रित', 'O'), ('करने', 'O'), ('वाले', 'O'), ('एक', 'O'), ('निजी', 'O'), ('वकील', 'O'), ('बन', 'O'), ('गए।', 'O')]
# [('फिजी', 'O'), ('का', 'O'), ('एक', 'O'), ('दूतावास', 'O'), ('वाशिंगटन', 'B-HumanSettlement'), ('डी', 'I-HumanSettlement'), ('सी', 'I-HumanSettlement'), ('में', 'O'), ('है', 'O')]
# [('उन्होंने', 'O'), ('नौकरी', 'O'), ('खोजने', 'O'), ('के', 'O'), ('लिए', 'O'), ('अपनी', 'O'), ('जेब', 'O'), ('में', 'O'), ('$', 'O'), ('१२५', 'O'), ('के', 'O'), ('साथ', 'O'), ('लॉस', 'B-HumanSettlement'), ('एंजेलिस', 'I-HumanSettlement'), ('पर', 'O'), ('जाने', 'O'), ('से', 'O'), ('पहले', 'O'), ('३', 'O'), ('साल', 'O'), ('तक', 'O'), ('सेना', 'O'), ('में', 'O'), ('सेवा', 'O'), ('की।', 'O')]
# [('दौड़', 'O'), ('शुरू', 'O'), ('हुई', 'O'), ('और', 'O'), ('ग्रेनोब्ल', 'B-HumanSettlement'), ('में', 'O'), ('समाप्त', 'O'), ('हो', 'O'), ('गई।', 'O')]
# [('एकजुटता', 'O'), ('के', 'O'), ('संदेश', 'O'), ('के', 'O'), ('रूप', 'O'), ('में', 'O'), ('दुबई', 'B-HumanSettlement'), ('में', 'O'), ('बुर्ज', 'B-Facility'), ('ख़लीफ़ा', 'I-Facility'), ('पर।', 'O')]
# [('प्राचीन', 'B-HumanSettlement'), ('मिस्र', 'I-HumanSettlement'), ('फिरौन', 'O'), ('तुथंखमुन', 'B-OtherPER'), ('कान', 'O'), ('की', 'O'), ('लोबों', 'O'), ('को', 'O'), ('फैलाने', 'O'), ('वाले', 'O'), ('सबसे', 'O'), ('पहले', 'O'), ('ज्ञात', 'O'), ('शासकों', 'O'), ('में', 'O'), ('से', 'O'), ('एक', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('२०१५', 'O'), ('में', 'O'), ('सब्राथा', 'B-HumanSettlement'), ('लीबिया', 'B-HumanSettlement'), ('के', 'O'), ('शहर', 'O'), ('में', 'O'), ('स्थापित', 'O'), ('किया', 'O'), ('गया', 'O'), ('था', 'O'), ('जिसमें', 'O'), ('१८', 'O'), ('परिसर', 'O'), ('राजधानी', 'O'), ('के', 'O'), ('तट', 'O'), ('के', 'O'), ('पश्चिम', 'O'), ('में', 'O'), ('पूरे', 'O'), ('शहरों', 'O'), ('में', 'O'), ('फैले', 'O'), ('थे', 'O'), ('त्रिपोली', 'B-HumanSettlement'), ('।', 'O')]
# [('चीन', 'B-HumanSettlement'), ('पर', 'O'), ('भेजा', 'O'), ('गया', 'O'), (';', 'O'), ('शिपिंग', 'O'), ('रजिस्टरों', 'O'), ('से', 'O'), ('गायब', 'O'), ('हो', 'O'), ('जाता', 'O'), ('है', 'O')]
# [('इसका', 'O'), ('मुख्यालय', 'O'), ('एम्स्टर्डम', 'B-HumanSettlement'), ('में', 'O'), ('स्थित', 'O'), ('है।', 'O')]
# [('क्लब', 'O'), ('ने', 'O'), ('अक्सर', 'O'), ('प्रदर्शित', 'O'), ('किया', 'O'), (';', 'O'), ('१९३५', 'O'), ('में', 'O'), ('आयोजित', 'O'), ('टोक्यो', 'B-HumanSettlement'), ('में', 'O'), ('इसकी', 'O'), ('पहली', 'O'), ('प्रदर्शनी।', 'O')]
# [('अपने', 'O'), ('मंत्री', 'O'), ('से', 'O'), ('पहले', 'O'), ('वह', 'O'), ('लीमा', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('प्रमुख', 'O'), ('रक्षा', 'O'), ('वकील', 'O'), ('थे।', 'O')]
# [('वह', 'O'), ('भारतवर्ष', 'B-HumanSettlement'), ('में', 'O'), ('कमर्शियल', 'O'), ('थिएटर', 'O'), ('के', 'O'), ('समर्थक', 'O'), ('और', 'O'), ('प्रमोटर', 'O'), ('हैं', 'O'), ('और', 'O'), ('उन्होंने', 'O'), ('पूरे', 'O'), ('घरों', 'O'), ('में', 'O'), ('चलने', 'O'), ('वाले', 'O'), ('विभिन्न', 'O'), ('टिकट', 'O'), ('वाले', 'O'), ('शो', 'O'), ('किए', 'O'), ('हैं।', 'O')]
# [('पनामा', 'O'), ('का', 'O'), ('वारसॉ', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('दूतावास', 'O'), ('है।', 'O')]
# [('उनका', 'O'), ('संबंध', 'O'), ('२०', 'O'), ('वीं', 'O'), ('शताब्दी', 'O'), ('के', 'O'), ('अंत', 'O'), ('में', 'O'), ('लॉस', 'B-HumanSettlement'), ('एंजेलिस', 'I-HumanSettlement'), ('में', 'O'), ('सांस्कृतिक', 'O'), ('घर्षण', 'O'), ('को', 'O'), ('रेखांकित', 'O'), ('करता', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('पनामा', 'B-HumanSettlement'), ('शहर', 'I-HumanSettlement'), ('के', 'O'), ('१००', 'O'), ('किमी', 'O'), ('पश्चिम', 'O'), ('में', 'O'), ('स्थित', 'O'), ('है।', 'O')]
# [('हॉट', 'O'), ('व्हील्स', 'O'), ('लुईविल', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('शो', 'O'), ('को', 'O'), ('स्थगित', 'O'), ('कर', 'O'), ('दिया।', 'O')]
# [('उन्होंने', 'O'), ('चर्च', 'O'), ('में', 'O'), ('गाया', 'O'), ('और', 'O'), ('बाल्टीमोर', 'B-HumanSettlement'), ('में', 'O'), ('विश्वविद्यालय', 'O'), ('में', 'O'), ('दवा', 'O'), ('का', 'O'), ('अध्ययन', 'O'), ('किया।', 'O')]
# [('यह', 'O'), ('यूनाइटेड', 'B-HumanSettlement'), ('किंगडम', 'I-HumanSettlement'), ('में', 'O'), ('संगीत', 'O'), ('में', 'O'), ('१९५८', 'O'), ('का', 'O'), ('सारांश', 'O'), ('है', 'O'), ('जिसमें', 'O'), ('उस', 'O'), ('वर्ष', 'O'), ('से', 'O'), ('आधिकारिक', 'O'), ('चार्ट', 'O'), ('भी', 'O'), ('शामिल', 'O'), ('है।', 'O')]
# [('कुछ', 'O'), ('बच्चे', 'O'), ('पास', 'O'), ('के', 'O'), ('शहरों', 'O'), ('और', 'O'), ('शहरों', 'O'), ('में', 'O'), ('नागरिकों', 'O'), ('के', 'O'), ('प्रवास', 'O'), ('के', 'O'), ('कारण', 'O'), ('स्कूल', 'O'), ('में', 'O'), ('भाग', 'O'), ('लेते', 'O'), ('हैं', 'O'), ('जैसे', 'O'), ('कोटद्वार', 'B-HumanSettlement'), ('और', 'O'), ('कभी', 'O'), ('-कभी', 'O'), ('आगे', 'O'), ('इन्द्रप्रस्थ', 'B-HumanSettlement'), ('जो', 'O'), ('दूर', 'O'), ('है।', 'O')]
# [('कंपनी', 'O'), ('की', 'O'), ('स्थापना', 'O'), ('१९९२', 'O'), ('में', 'O'), ('बुरगास', 'B-HumanSettlement'), ('में', 'O'), ('की', 'O'), ('गई', 'O'), ('थी', 'O'), ('और', 'O'), ('इसका', 'O'), ('मुख्यालय', 'O'), ('है।', 'O')]
# [('वह', 'O'), ('मिनोट', 'B-HumanSettlement'), ('में', 'O'), ('बस', 'O'), ('गया', 'O'), ('और', 'O'), ('एक', 'O'), ('१००', 'O'), ('साल', 'O'), ('की', 'O'), ('उम्र', 'O'), ('में', 'O'), ('खरीदा', 'O'), ('बाढ़', 'O'), ('क्षतिग्रस्त', 'O'), ('घर', 'O'), ('जिसे', 'O'), ('वह', 'O'), ('खुद', 'O'), ('को', 'O'), ('बहाल', 'O'), ('कर', 'O'), ('रहा', 'O'), ('है।', 'O')]
# [('विलियम्स', 'O'), ('का', 'O'), ('जन्म', 'O'), ('चार्ल्सटन', 'B-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था।', 'O')]
# [('बंगाल', 'O'), ('टाइगर्स', 'O'), ('भारतवर्ष', 'B-HumanSettlement'), ('से', 'O'), ('आते', 'O'), ('हैं', 'O'), ('और', 'O'), ('विलुप्त', 'O'), ('होने', 'O'), ('के', 'O'), ('कगार', 'O'), ('पर', 'O'), ('रहते', 'O'), ('हैं', 'O'), ('जिसमें', 'O'), ('२०००', 'O'), ('से', 'O'), ('कम', 'O'), ('जंगली', 'O'), ('में', 'O'), ('रहते', 'O'), ('हैं।', 'O')]
# [('अबुल', 'B-Politician'), ('फजल', 'I-Politician'), ('मुग़ल', 'B-HumanSettlement'), ('राजवंश', 'I-HumanSettlement'), ('सम्राट', 'O'), ('अकबर', 'B-OtherPER'), ('का', 'O'), ('विजियर', 'O')]
# [('पहले', 'O'), ('से', 'O'), ('ही', 'O'), ('रिकॉर्ड', 'O'), ('किए', 'O'), ('गए', 'O'), ('गीतों', 'O'), ('के', 'O'), ('एक', 'O'), ('जोड़े', 'O'), ('के', 'O'), ('साथ', 'O'), ('वह', 'O'), ('स्टॉकहोम', 'B-HumanSettlement'), ('से', 'O'), ('malmö', 'B-Station'), ('तक', 'O'), ('चले', 'O'), ('गए।', 'O')]
# [('विद्वान', 'O'), ('इस', 'O'), ('परिधान', 'O'), ('को', 'O'), ('साड़ी', 'B-Clothing'), ('भारतवर्ष', 'B-HumanSettlement'), ('के', 'O'), ('लिए', 'O'), ('ट्रेस', 'O'), ('करते', 'O'), ('हैं।', 'O')]
# [('झुग्गियों', 'O'), ('को', 'O'), ('विकसित', 'O'), ('करने', 'O'), ('का', 'O'), ('प्रयास', 'O'), ('करने', 'O'), ('के', 'O'), ('बजाय', 'O'), ('चीन', 'B-HumanSettlement'), ('अक्सर', 'O'), ('उन्हें', 'O'), ('इसके', 'O'), ('बजाय', 'O'), ('ध्वस्त', 'O'), ('कर', 'O'), ('देता', 'O'), ('है।', 'O')]
# [('इसका', 'O'), ('नाम', 'O'), ('इसके', 'O'), ('प्रशासनिक', 'O'), ('केंद्र', 'O'), ('के', 'O'), ('नाम', 'O'), ('पर', 'O'), ('रखा', 'O'), ('गया', 'O'), ('है', 'O'), ('जो', 'O'), ('रूस', 'B-HumanSettlement'), ('शहर', 'O'), ('के', 'O'), ('शहर', 'O'), ('की', 'O'), ('राजधानी', 'O'), ('भी', 'O'), ('है।', 'O')]
# [('नीचे', 'O'), ('दी', 'O'), ('गई', 'O'), ('तालिका', 'O'), ('में', 'O'), ('यू', 'B-HumanSettlement'), ('एस', 'I-HumanSettlement'), ('में', 'O'), ('दिए', 'O'), ('गए', 'O'), ('लाभों', 'O'), ('की', 'O'), ('एक', 'O'), ('सूची', 'O'), ('है', 'O'), ('जो', 'O'), ('इनमें', 'O'), ('से', 'O'), ('कुछ', 'O'), ('नेटवर्क', 'O'), ('में', 'O'), ('उपभोक्ता', 'B-OtherPER'), ('क्रेडिट', 'O'), ('कार्ड', 'O'), ('के', 'O'), ('लिए', 'O'), ('है।', 'O')]
# [('इस', 'O'), ('कार्यक्रम', 'O'), ('में', 'O'), ('ऑस्ट्रेलिया', 'B-HumanSettlement'), ('के', 'O'), ('आसपास', 'O'), ('१८', 'O'), ('५००', 'O'), ('किलोमीटर', 'O'), ('की', 'O'), ('दूरी', 'O'), ('तय', 'O'), ('की', 'O'), ('गई।', 'O')]
# [('ऐशविल', 'B-HumanSettlement'), ('में', 'O'), ('अज्ञात', 'O'), ('कारणों', 'O'), ('से', 'O'), ('पुलिस', 'O'), ('द्वारा', 'O'), ('एक', 'O'), ('मेडिक', 'O'), ('स्टेशन', 'O'), ('को', 'O'), ('नष्ट', 'O'), ('कर', 'O'), ('दिया', 'O'), ('गया', 'O'), ('था।', 'O')]
# [('यह', 'O'), ('१८', 'O'), ('वीं', 'O'), ('शताब्दी', 'O'), ('में', 'O'), ('एक', 'O'), ('एकल', 'O'), ('पांडुलिपि', 'O'), ('डेटिंग', 'O'), ('में', 'O'), ('जीवित', 'O'), ('है', 'O'), ('और', 'O'), ('पहली', 'O'), ('बार', 'O'), ('१९१४', 'O'), ('में', 'O'), ('कोपनहेगन', 'B-HumanSettlement'), ('में', 'O'), ('प्रकाशित', 'O'), ('हुआ', 'O'), ('था।', 'O')]
# [('टेंटा', 'O'), ('उत्तरी', 'O'), ('इथियोपिया', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('शहर', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('चेल्म', 'B-HumanSettlement'), ('के', 'O'), ('लगभग', 'O'), ('पश्चिम', 'O'), ('में', 'O'), ('स्थित', 'O'), ('है', 'O'), ('और', 'O'), ('क्षेत्रीय', 'O'), ('राजधानी', 'O'), ('लुबलिन', 'B-HumanSettlement'), ('के', 'O'), ('पूर्व', 'O'), ('में', 'O'), ('है।', 'O')]
# [('निकटतम', 'O'), ('अंतरराष्ट्रीय', 'O'), ('हवाई', 'O'), ('अड्डा', 'O'), ('पालम', 'B-Station'), ('हवाई', 'I-Station'), ('अड्डा', 'I-Station'), ('नई', 'B-HumanSettlement'), ('दिल्ली', 'I-HumanSettlement'), ('१७८', 'O'), ('किमी', 'O'), ('दूर', 'O'), ('है।', 'O')]
# [('अपने', 'O'), ('संग्रह', 'O'), ('में', 'O'), ('३', 'O'), ('मिलियन', 'O'), ('से', 'O'), ('अधिक', 'O'), ('वस्तुओं', 'O'), ('के', 'O'), ('साथ', 'O'), ('लाइब्रेरी', 'O'), ('स्विट्जरलैण्ड', 'B-HumanSettlement'), ('में', 'O'), ('सबसे', 'O'), ('बड़ी', 'O'), ('में', 'O'), ('से', 'O'), ('एक', 'O'), ('है।', 'O')]
# [('जवाब', 'O'), ('में', 'O'), ('मोहनदास', 'B-Politician'), ('करमचंद', 'I-Politician'), ('गांधी', 'I-Politician'), ('एक', 'O'), ('अपील', 'O'), ('के', 'O'), ('रूप', 'O'), ('में', 'O'), ('इन्द्रप्रस्थ', 'B-HumanSettlement'), ('से', 'O'), ('पहुंचे।', 'O')]
# [('इसके', 'O'), ('परिणामस्वरूप', 'O'), ('रंगभेद', 'O'), ('नीति', 'O'), ('दक्षिण', 'B-HumanSettlement'), ('अफ़्रीका', 'I-HumanSettlement'), ('का', 'O'), ('विद्रोही', 'O'), ('दौरा', 'O'), ('हुआ', 'O'), ('(', 'O'), ('जिसे', 'O'), ('उस', 'O'), ('समय', 'O'), ('अंतर्राष्ट्रीय', 'O'), ('क्रिकेट', 'O'), ('से', 'O'), ('प्रतिबंधित', 'O'), ('कर', 'O'), ('दिया', 'O'), ('गया', 'O'), ('था', 'O'), (')', 'O'), ('।', 'O')]
# [('१९४३', 'O'), ('में', 'O'), ('एक', 'O'), ('कमीशन', 'O'), ('किया', 'O'), ('गया', 'O'), ('था', 'O'), ('और', 'O'), ('१९५९', 'O'), ('में', 'O'), ('पाकिस्तान', 'B-HumanSettlement'), ('में', 'O'), ('स्थानांतरित', 'O'), ('कर', 'O'), ('दिया', 'O'), ('गया', 'O'), ('था', 'O')]
# [('एम्स्टर्डम', 'B-HumanSettlement'), ('अधिकारियों', 'O'), ('द्वारा', 'O'), ('उनका', 'O'), ('बहिष्कार', 'O'), ('पारंपरिक', 'O'), ('अभ्यास', 'O'), ('के', 'O'), ('बजाय', 'O'), ('चर्च', 'B-ORG'), ('के', 'O'), ('डर', 'O'), ('से', 'O'), ('प्रेरित', 'O'), ('था।', 'O')]
# [('१९९३', 'O'), ('के', 'O'), ('बाद', 'O'), ('से', 'O'), ('एक', 'O'), ('कुश्ती', 'O'), ('टूर्नामेंट', 'O'), ('को', 'O'), ('उनके', 'O'), ('सम्मान', 'O'), ('में', 'O'), ('ताम्बोव', 'B-HumanSettlement'), ('में', 'O'), ('आयोजित', 'O'), ('किया', 'O'), ('गया', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('मेडागास्कर', 'B-HumanSettlement'), ('पर', 'O'), ('पाया', 'O'), ('जाता', 'O'), ('है।', 'O')]
# [('ऑस्ट्रिया-हंगरी', 'B-HumanSettlement'), ('स्थिति', 'O'), ('को', 'O'), ('इसकी', 'O'), ('नीति', 'O'), ('द्वारा', 'O'), ('सर्बिया', 'B-HumanSettlement'), ('की', 'O'), ('ओर', 'O'), ('निर्धारित', 'O'), ('किया', 'O'), ('गया', 'O'), ('था।', 'O')]
# [('गैर', 'O'), ('-जिम्मेदार', 'O'), ('कहना', 'O'), ('पसंद', 'O'), ('है', 'O'), (')', 'O'), ('नई', 'B-HumanSettlement'), ('दिल्ली', 'I-HumanSettlement'), ('से', 'O'), ('प्रकाशक', 'O'), ('ने', 'O'), ('अपना', 'O'), ('मूल', 'O'), ('खो', 'O'), ('दिया', 'O')]
# [('मॉस', 'O'), ('न्यूज़ीलैण्ड', 'B-HumanSettlement'), ('में', 'O'), ('चले', 'O'), ('गए', 'O'), ('जब', 'O'), ('उनके', 'O'), ('पिता', 'O'), ('ने', 'O'), ('अपने', 'O'), ('भाग्य', 'O'), ('को', 'O'), ('साझा', 'O'), ('करने', 'O'), ('से', 'O'), ('बचने', 'O'), ('की', 'O'), ('उम्मीद', 'O'), ('में', 'O'), ('यक्ष्मा', 'B-Disease'), ('पर', 'O'), ('दम', 'O'), ('तोड़', 'O'), ('दिया।', 'O')]
# [('ब्राउन', 'O'), ('वर्तमान', 'O'), ('में', 'O'), ('अपने', 'O'), ('परिवार', 'O'), ('के', 'O'), ('साथ', 'O'), ('लॉस', 'B-HumanSettlement'), ('एंजेलिस', 'I-HumanSettlement'), ('में', 'O'), ('रहता', 'O'), ('है।', 'O')]
# [('दो', 'O'), ('साल', 'O'), ('बाद', 'O'), ('वह', 'O'), ('सीऐटल', 'B-HumanSettlement'), ('की', 'O'), ('यात्रा', 'O'), ('करता', 'O'), ('है', 'O'), ('और', 'O'), ('एक', 'O'), ('नाइट', 'O'), ('क्लब', 'O'), ('बैंड', 'O'), ('में', 'O'), ('शामिल', 'O'), ('होता', 'O'), ('है', 'O'), ('हालांकि', 'O'), ('क्लब', 'O'), ('का', 'O'), ('मालिक', 'O'), ('यौन', 'O'), ('एहसान', 'O'), ('की', 'O'), ('मांग', 'O'), ('करता', 'O'), ('है', 'O'), ('और', 'O'), ('अपने', 'O'), ('पैसे', 'O'), ('और', 'O'), ('करियर', 'O'), ('को', 'O'), ('नियंत्रित', 'O'), ('करता', 'O'), ('है।', 'O')]
# [('तिघे', 'O'), ('का', 'O'), ('जन्म', 'O'), ('और', 'O'), ('पालन', 'O'), ('-पोषण', 'O'), ('न्यूयॉर्क', 'B-HumanSettlement'), ('शहर', 'I-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था।', 'O')]
# [('गाँव', 'O'), ('में', 'O'), ('पाए', 'O'), ('गए', 'O'), ('अवशेषों', 'O'), ('से', 'O'), ('संकेत', 'O'), ('मिलता', 'O'), ('है', 'O'), ('कि', 'O'), ('यह', 'O'), ('बाइज़ेंटाइन', 'B-HumanSettlement'), ('साम्राज्य', 'I-HumanSettlement'), ('युग', 'O'), ('के', 'O'), ('दौरान', 'O'), ('आबाद', 'O'), ('था।', 'O')]
# [('निकारागुआ', 'B-HumanSettlement'), ('में', 'O'), ('टोकिनो', 'O'), ('कुछ', 'O'), ('तरीकों', 'O'), ('से', 'O'), ('तैयार', 'O'), ('किया', 'O'), ('जाता', 'O'), ('है।', 'O')]
# [('२००२', 'O'), ('में', 'O'), ('बीएई', 'B-AerospaceManufacturer'), ('सिस्टम्स', 'I-AerospaceManufacturer'), ('बेची', 'O'), ('गई', 'O'), ('तंज़ानिया', 'B-HumanSettlement'), ('एक', 'O'), ('अतिप्रवाहित', 'O'), ('रडार।', 'O')]
# [('१९५५', 'O'), ('में', 'O'), ('उन्होंने', 'O'), ('नीदरलैण्ड', 'B-HumanSettlement'), ('और', 'O'), ('जर्मनी', 'B-HumanSettlement'), ('में', 'O'), ('आयोजित', 'O'), ('अंतर्राष्ट्रीय', 'O'), ('एयर', 'O'), ('शो', 'O'), ('में', 'O'), ('एक', 'O'), ('स्काइडाइवर', 'O'), ('के', 'O'), ('रूप', 'O'), ('में', 'O'), ('भाग', 'O'), ('लिया।', 'O')]
# [('अंगोला', 'B-HumanSettlement'), ('में', 'O'), ('अंगोला', 'B-ORG'), ('पूर्ण', 'I-ORG'), ('स्वतंत्रता', 'I-ORG'), ('राष्ट्रीय', 'I-ORG'), ('संघ', 'I-ORG'), ('के', 'O'), ('खिलाफ', 'O'), ('प्रतिबंधों', 'O'), ('की', 'O'), ('निगरानी', 'O'), ('के', 'O'), ('प्रतिबंधों', 'O'), ('का', 'O'), ('विस्तार', 'O'), ('करता', 'O'), ('है', 'O')]
# [('उनके', 'O'), ('काम', 'O'), ('को', 'O'), ('आज', 'O'), ('यू', 'B-HumanSettlement'), ('एस', 'I-HumanSettlement'), ('और', 'O'), ('जर्मनी', 'B-HumanSettlement'), ('में', 'O'), ('कई', 'O'), ('दीर्घाओं', 'O'), ('में', 'O'), ('सक्रिय', 'O'), ('रूप', 'O'), ('से', 'O'), ('कारोबार', 'O'), ('किया', 'O'), ('जाता', 'O'), ('है।', 'O')]
# [('कैंपबेल', 'O'), ('नैशुआ', 'B-HumanSettlement'), ('से', 'O'), ('एक', 'O'), ('वकील', 'O'), ('है।', 'O')]
# [('यह', 'O'), ('क्षेत्र', 'O'), ('द्वारा', 'O'), ('आयोजित', 'O'), ('घाना', 'B-HumanSettlement'), ('में', 'O'), ('रेडियो', 'O'), ('स्टेशनों', 'O'), ('की', 'O'), ('सूची', 'O'), ('की', 'O'), ('एक', 'O'), ('सूची', 'O'), ('है।', 'O')]
# [('पोस्ट', 'O'), ('शौच', 'O'), ('के', 'O'), ('लिए', 'O'), ('टॉयलेट', 'O'), ('पेपर', 'O'), ('का', 'O'), ('उपयोग', 'O'), ('पहले', 'O'), ('चीन', 'B-HumanSettlement'), ('में', 'O'), ('शुरू', 'O'), ('हुआ।', 'O')]
# [('वर्ष', 'O'), ('२०२१', 'O'), ('में', 'O'), ('घटनाएँ', 'O'), ('टोगो', 'B-HumanSettlement'), ('में।', 'O')]
# [('निम्नलिखित', 'O'), ('संग्रहालयों', 'B-OtherLOC'), ('और', 'O'), ('कला', 'O'), ('दीर्घाएँ', 'O'), ('कैम्ब्रिज', 'B-HumanSettlement'), ('इंग्लैण्ड', 'B-HumanSettlement'), ('में', 'O'), ('स्थित', 'O'), ('हैं', 'O'), (':', 'O')]
# [('इसमें', 'O'), ('कोता', 'B-HumanSettlement'), ('किनाबालू', 'I-HumanSettlement'), ('और', 'O'), ('कुचिंग', 'B-HumanSettlement'), ('में', 'O'), ('क्षेत्रीय', 'O'), ('स्टेशन', 'O'), ('भी', 'O'), ('हैं।', 'O')]
# [('बाद', 'O'), ('में', 'O'), ('उनके', 'O'), ('पास', 'O'), ('एक', 'O'), ('पूर्व', 'O'), ('अभिनेता', 'O'), ('के', 'O'), ('साथ', 'O'), ('पेय', 'O'), ('है', 'O'), ('जो', 'O'), ('वियतनाम', 'B-HumanSettlement'), ('में', 'O'), ('कारोबार', 'O'), ('कर', 'O'), ('रहा', 'O'), ('था।', 'O')]
# [('७५', 'O'), ('वर्ष', 'O'), ('की', 'O'), ('आयु', 'O'), ('में', 'O'), ('सिटी', 'B-HumanSettlement'), ('ऑफ़', 'I-HumanSettlement'), ('वेस्टमिंस्टर', 'I-HumanSettlement'), ('में', 'O'), ('उनकी', 'O'), ('मृत्यु', 'O'), ('हो', 'O'), ('गई।', 'O')]
# [('वह', 'O'), ('१९९०', 'O'), ('से', 'O'), ('१९९२', 'O'), ('तक', 'O'), ('चेकोस्लोवेकिया', 'B-HumanSettlement'), ('वैक्लेव', 'B-Politician'), ('हैवेल', 'I-Politician'), ('के', 'O'), ('पूर्व', 'O'), ('अध्यक्ष', 'O'), ('के', 'O'), ('मानवाधिकार', 'O'), ('सलाहकार', 'O'), ('थे।', 'O')]
# [('वह', 'O'), ('रूडा', 'B-HumanSettlement'), ('सलास्का', 'I-HumanSettlement'), ('में', 'O'), ('हाई', 'O'), ('स्कूल', 'O'), ('में', 'O'), ('गया', 'O'), ('और', 'O'), ('फिर', 'O'), ('अपनी', 'O'), ('पहल', 'O'), ('पर', 'O'), ('वह', 'O'), ('क्रकाउ', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('प्रतिष्ठित', 'O'), ('हाई', 'O'), ('स्कूल', 'O'), ('में', 'O'), ('स्थानांतरित', 'O'), ('हो', 'O'), ('गया', 'O'), ('जहां', 'O'), ('उसने', 'O'), ('मैट्रिक', 'O'), ('किया।', 'O')]
# [('एयरलाइनर', 'O'), ('ने', 'O'), ('जर्सी', 'B-ORG'), ('एन', 'O'), ('रूट', 'O'), ('से', 'O'), ('साउथैम्प्टन', 'B-HumanSettlement'), ('से', 'O'), ('दूर', 'O'), ('कर', 'O'), ('दिया', 'O'), ('था।', 'O')]
# [('वह', 'O'), ('वर्तमान', 'O'), ('में', 'O'), ('लॉस', 'B-HumanSettlement'), ('एंजेलिस', 'I-HumanSettlement'), ('में', 'O'), ('रहता', 'O'), ('है', 'O'), ('और', 'O'), ('विभिन्न', 'O'), ('अंतरराष्ट्रीय', 'O'), ('और', 'O'), ('घरेलू', 'O'), ('कृत्यों', 'O'), ('के', 'O'), ('लिए', 'O'), ('लिखना', 'O'), ('और', 'O'), ('उत्पादन', 'O'), ('करना', 'O'), ('जारी', 'O'), ('रखता', 'O'), ('है।', 'O')]
# [('प्रजातियों', 'O'), ('का', 'O'), ('नाम', 'O'), ('इसकी', 'O'), ('खोज', 'O'), ('के', 'O'), ('स्थान', 'O'), ('के', 'O'), ('संदर्भ', 'O'), ('में', 'O'), ('दिया', 'O'), ('गया', 'O'), ('था', 'O'), ('लोबात्से', 'B-HumanSettlement'), ('।', 'O')]
# [('एक', 'O'), ('अध्ययन', 'O'), ('में', 'O'), ('पाया', 'O'), ('गया', 'O'), ('है', 'O'), ('कि', 'O'), ('लखनउ', 'B-HumanSettlement'), ('(', 'O'), ('भारत', 'O'), (')', 'O'), ('बाजार', 'O'), ('से', 'O'), ('अध्ययन', 'O'), ('किए', 'O'), ('गए', 'O'), ('१७८', 'O'), ('फ़ॉइल', 'O'), ('में', 'O'), ('से', 'O'), ('लगभग', 'O'), ('१०', 'O'), ('%', 'O'), ('एल्युमिनियम', 'B-Medication/Vaccine'), ('से', 'O'), ('बने', 'O'), ('थे।', 'O')]
# [('उनका', 'O'), ('जन्म', 'O'), ('१९२६', 'O'), ('में', 'O'), ('लियोगेन', 'B-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था', 'O'), ('और', 'O'), ('उन्होंने', 'O'), ('अपने', 'O'), ('जीवन', 'O'), ('में', 'O'), ('रंगीन', 'O'), ('सड़क', 'O'), ('के', 'O'), ('दृश्यों', 'O'), ('और', 'O'), ('ग्रामीण', 'O'), ('दृश्यों', 'O'), ('को', 'O'), ('चित्रित', 'O'), ('किया', 'O'), ('फिर', 'O'), ('१९८८', 'O'), ('में', 'O'), ('उनकी', 'O'), ('मृत्यु', 'O'), ('हो', 'O'), ('गई।', 'O')]
# [('यू', 'B-HumanSettlement'), ('एस', 'I-HumanSettlement'), ('(', 'O'), ('सभी', 'O'), ('में', 'O'), ('३', 'O'), ('०००', 'O'), (')', 'O'), ('में', 'O'), ('उनके', 'O'), ('प्रदर्शन', 'O'), ('के', 'O'), ('माध्यम', 'O'), ('से', 'O'), ('समूह', 'O'), ('ने', 'O'), ('आम', 'O'), ('जनता', 'O'), ('के', 'O'), ('लिए', 'O'), ('टक्कर', 'O'), ('संगीत', 'O'), ('को', 'O'), ('बढ़ावा', 'O'), ('देने', 'O'), ('के', 'O'), ('लिए', 'O'), ('बहुत', 'O'), ('कुछ', 'O'), ('किया।', 'O')]
# [('इसने', 'O'), ('फ़िलीपीन्स', 'B-HumanSettlement'), ('से', 'O'), ('उष्णकटिबंधीय', 'O'), ('पौधों', 'O'), ('की', 'O'), ('प्रदर्शनी', 'O'), ('के', 'O'), ('लिए', 'O'), ('ग्रीनहाउस', 'B-Facility'), ('के', 'O'), ('रूप', 'O'), ('में', 'O'), ('कार्य', 'O'), ('किया।', 'O')]
# [('सप्ताह', 'O'), ('विभिन्न', 'O'), ('कार्यशालाओं', 'O'), ('और', 'O'), ('खरीदारी', 'O'), ('के', 'O'), ('दिनों', 'O'), ('के', 'O'), ('साथ', 'O'), ('जारी', 'O'), ('रहा', 'O'), ('दो', 'O'), ('दिनों', 'O'), ('के', 'O'), ('फैशन', 'O'), ('शो', 'O'), ('में', 'O'), ('ताम्पा', 'B-HumanSettlement'), ('में', 'O'), ('समापन।', 'O')]
# [('फाल्को', 'O'), ('का', 'O'), ('जन्म', 'O'), ('बेथनल', 'B-HumanSettlement'), ('ग्रीन', 'I-HumanSettlement'), ('लंदन,इंग्लॅण्ड', 'B-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था।', 'O')]
# [('तुर्की', 'O'), ('के', 'O'), ('पास', 'O'), ('बर्न', 'B-HumanSettlement'), ('में', 'O'), ('एक', 'O'), ('दूतावास', 'O'), ('है', 'O'), ('और', 'O'), ('ज़्यूरिख़', 'B-HumanSettlement'), ('और', 'O'), ('जिनेवा', 'B-HumanSettlement'), ('में', 'O'), ('जनरल', 'O'), ('कॉन्सुलेट', 'O'), ('करता', 'O'), ('है।', 'O')]
# [('फाउंडेशन', 'O'), ('की', 'O'), ('इमारत', 'O'), ('मकुर्डी', 'B-HumanSettlement'), ('में', 'O'), ('पांच', 'O'), ('हेक्टेयर', 'O'), ('भूमि', 'O'), ('पर', 'O'), ('है', 'O'), ('और', 'O'), ('इसमें', 'O'), ('एक', 'O'), ('आर्ट', 'O'), ('गैलरी', 'O'), ('सम्मेलन', 'O'), ('कक्ष', 'O'), ('मनोरंजक', 'O'), ('केंद्र', 'O'), ('और', 'O'), ('शैले', 'O'), ('शामिल', 'O'), ('हैं।', 'O')]
# [('यह', 'O'), ('चार', 'O'), ('टीमों', 'O'), ('द्वारा', 'O'), ('लड़ा', 'O'), ('गया', 'O'), ('था', 'O'), ('एक', 'O'), ('इटली', 'B-HumanSettlement'), ('एक', 'O'), ('स्पेन', 'B-HumanSettlement'), ('से', 'O'), ('और', 'O'), ('दो', 'O'), ('मेजबान', 'O'), ('राष्ट्र', 'O'), ('इंग्लैण्ड', 'B-HumanSettlement'), ('से', 'O'), ('दो।', 'O')]
# [('लिंडे', 'O'), ('का', 'O'), ('जन्म', 'O'), ('स्कॉवडे', 'B-HumanSettlement'), ('में', 'O'), ('हुआ', 'O'), ('था', 'O'), ('और', 'O'), ('वहीं', 'O'), ('बड़ा', 'O'), ('हुआ।', 'O')]
# [('माली', 'B-HumanSettlement'), ('में', 'O'), ('खानाबदोश', 'O'), ('भी', 'O'), ('प्रभावित', 'O'), ('हुए।', 'O')]
# [('१९३७', 'O'), ('में', 'O'), ('उन्होंने', 'O'), ('इंग्लैण्ड', 'B-HumanSettlement'), ('फ़्रांस', 'B-HumanSettlement'), ('और', 'O'), ('जर्मनी', 'B-HumanSettlement'), ('की', 'O'), ('यात्रा', 'O'), ('की।', 'O')]

# %%
SEQ_LEN = 30

# Create word_to_idx and tag_to_idx mappings
word_to_idx = {"<PAD>": 0, "<UNK>": 1}
tag_to_idx = {"<PAD>": 0}


def preprocess(dataset):
    # Extract sentences and tags
    sent = [[token.lower() for token, tag in sentence] for sentence in dataset]
    tags = [[tag for token, tag in sentence] for sentence in dataset]

    for i in range(len(sent)):
        while len(sent[i]) < SEQ_LEN:
            sent[i].append('<PAD>')
            tags[i].append('<PAD>')

        if len(sent[i]) > SEQ_LEN:
            sent[i] = sent[i][:SEQ_LEN]
            tags[i] = tags[i][:SEQ_LEN]
    
    for sentence_tags in tags:
        for tag in sentence_tags:
            if tag not in tag_to_idx:
                tag_to_idx[tag] = len(tag_to_idx)
    
    for sentence in sent:
        for word in sentence:
            if word not in word_to_idx:
                word_to_idx[word] = len(word_to_idx)

    # Convert words and tags to indices
    X = torch.tensor([[word_to_idx.get(word, 1) for word in sentence] for sentence in sent], dtype=torch.int).type(torch.LongTensor)
    Y = torch.tensor([[tag_to_idx[tag] for tag in sentence] for sentence in tags], dtype=torch.int).type(torch.LongTensor)
    
    return X, Y

# %%
train_X, train_Y = preprocess(train_dataset)
dev_X, dev_Y = preprocess(dev_dataset)
test_X, test_Y = preprocess(test_dataset)

# %%
# Print the sizes of the datasets
print(f"Number of training examples: {len(train_X)}")
print(f"Number of validation examples: {len(dev_X)}")
print(f"Number of testing examples: {len(test_X)}")
# for i in range(100):
#     print(train_X[i])
# Out:
# Number of training examples: 9632
# Number of validation examples: 514
# Number of testing examples: 18399

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pytorch_lightning as pl

class NERModel(pl.LightningModule):
    def __init__(self, vocab_size, tagset_size, embedding_dim, hidden_dim, num_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim) #B * seq_len, B * seq_len * embedding_dim
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=num_layers, bidirectional=True)
        self.fc = nn.Linear(2*hidden_dim, tagset_size)
        self.loss_fn = nn.CrossEntropyLoss()
    
    def forward(self, x):
        embeds = self.embedding(x)
        #print(embeds.shape)
        lstm_out, _ = self.lstm(embeds)
        tag_space = self.fc(lstm_out)
        tag_scores = nn.functional.log_softmax(tag_space, dim=2)
        return tag_scores
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('train_loss', loss)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('val_loss', loss)
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('test_loss', loss)
        return loss
    
    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters())
        return optimizer

# %%
from torch.utils.data import DataLoader, TensorDataset
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

EMBEDDING_DIM = 125
HIDDEN_DIM    = 125
NUM_EPOCHS    = 10 
BATCH_SIZE    = 10

train_dataset = TensorDataset(train_X, train_Y)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

val_dataset = TensorDataset(dev_X, dev_Y)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

test_dataset = TensorDataset(test_X, test_Y)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
model = NERModel(vocab_size=len(word_to_idx), tagset_size=len(tag_to_idx), embedding_dim=EMBEDDING_DIM, hidden_dim=HIDDEN_DIM)
early_stopping = EarlyStopping(monitor="val_loss", patience=3, mode="min")
trainer = pl.Trainer(max_epochs=NUM_EPOCHS, callbacks=[early_stopping])
trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)

trainer.test(dataloaders=test_loader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | embedding | Embedding        | 3.8 M
# 1 | lstm      | LSTM             | 252 K
# 2 | fc        | Linear           | 17.1 K
# 3 | loss_fn   | CrossEntropyLoss | 0
# -----------------------------------------------
# 4.1 M     Trainable params
# 0         Non-trainable params
# 4.1 M     Total params
# 16.371    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at /content/lightning_logs/version_2/checkpoints/epoch=6-step=6748.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at /content/lightning_logs/version_2/checkpoints/epoch=6-step=6748.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │    0.2674734592437744     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.2674734592437744}]

# %%
from sklearn.metrics import classification_report

# define idx_to_tag
idx_to_tag = {idx: tag for tag, idx in tag_to_idx.items()}

# define device
device = torch.device('cpu')

# Create a dataloader for the test set
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Set the model to evaluation mode
model.eval()

y_true = []
y_pred = []

with torch.no_grad():
    for x, y in test_loader:
        # Move the data to the device
        x = x.to(device)
        y = y.to(device)

        # Forward pass
        y_hat = model(x)

        # Compute the predicted tags
        y_pred += [idx_to_tag[i] for i in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

        # Compute the true tags
        y_true += [idx_to_tag[i] for i in y.cpu().numpy().flatten().tolist()]

print(classification_report(y_true, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
#                   <PAD>       1.00      1.00      1.00    258203
# B-AerospaceManufacturer       0.21      0.05      0.08        85
#   B-AnatomicalStructure       0.68      0.61      0.64       489
#               B-ArtWork       0.17      0.00      0.00       426
#                B-Artist       0.48      0.40      0.44      1852
#               B-Athlete       0.62      0.56      0.59      1171
#       B-CarManufacturer       0.78      0.85      0.81       146
#                B-Cleric       0.54      0.80      0.65       188
#              B-Clothing       0.48      0.82      0.61        77
#               B-Disease       0.65      0.65      0.65       633
#                 B-Drink       0.59      0.65      0.62       135
#              B-Facility       0.43      0.47      0.45       859
#                  B-Food       0.47      0.60      0.52       428
#       B-HumanSettlement       0.76      0.65      0.70      5825
#      B-MedicalProcedure       0.54      0.66      0.60       334
#    B-Medication/Vaccine       0.66      0.61      0.63       377
#            B-MusicalGRP       0.45      0.80      0.58       173
#           B-MusicalWork       0.46      0.70      0.56        44
#                   B-ORG       0.75      0.68      0.71      1847
#              B-OtherLOC       0.71      0.67      0.69       231
#              B-OtherPER       0.35      0.37      0.36       741
#             B-OtherPROD       0.38      0.42      0.40       778
#            B-Politician       0.59      0.42      0.49      1155
#           B-PrivateCorp       0.82      0.79      0.80        84
#            B-PublicCorp       0.56      0.66      0.60       416
#             B-Scientist       0.34      0.62      0.44       132
#              B-Software       0.74      0.68      0.71       701
#             B-SportsGRP       0.91      0.83      0.86      1142
#         B-SportsManager       0.22      0.02      0.03       493
#               B-Station       0.79      0.69      0.74       256
#               B-Symptom       0.73      0.76      0.75       140
#               B-Vehicle       0.68      0.77      0.72       190
#            B-VisualWork       0.51      0.38      0.43       753
#           B-WrittenWork       0.62      0.63      0.63       878
# I-AerospaceManufacturer       1.00      0.03      0.06        94
#   I-AnatomicalStructure       0.82      0.50      0.62       109
#               I-ArtWork       0.67      0.01      0.02      1020
#                I-Artist       0.55      0.43      0.48      1931
#               I-Athlete       0.63      0.54      0.58      1260
#       I-CarManufacturer       0.95      0.81      0.87        69
#                I-Cleric       0.79      0.88      0.83       200
#              I-Clothing       0.60      0.43      0.50         7
#               I-Disease       0.72      0.65      0.68       303
#                 I-Drink       0.70      0.48      0.57        63
#              I-Facility       0.51      0.47      0.49       747
#                  I-Food       0.73      0.51      0.60       151
#       I-HumanSettlement       0.82      0.64      0.72      1712
#      I-MedicalProcedure       0.79      0.68      0.73       222
#    I-Medication/Vaccine       0.76      0.61      0.67       137
#            I-MusicalGRP       0.59      0.86      0.70       143
#           I-MusicalWork       0.28      0.76      0.41        29
#                   I-ORG       0.87      0.77      0.82      3046
#              I-OtherLOC       0.81      0.72      0.76       259
#              I-OtherPER       0.46      0.41      0.43       887
#             I-OtherPROD       0.58      0.36      0.44       434
#            I-Politician       0.61      0.48      0.54      1420
#           I-PrivateCorp       1.00      0.83      0.91        81
#            I-PublicCorp       0.67      0.66      0.67       252
#             I-Scientist       0.45      0.60      0.52       175
#              I-Software       0.73      0.58      0.65       360
#             I-SportsGRP       0.91      0.82      0.86      1882
#         I-SportsManager       0.23      0.01      0.02       659
#               I-Station       0.83      0.83      0.83       533
#               I-Symptom       0.58      0.48      0.53        29
#               I-Vehicle       0.59      0.75      0.66       100
#            I-VisualWork       0.66      0.49      0.56      1377
#           I-WrittenWork       0.73      0.72      0.72      1122
#                       O       0.96      0.98      0.97    249775
#
#                accuracy                           0.96    551970
#               macro avg       0.64      0.59      0.59    551970
#            weighted avg       0.95      0.96      0.95    551970

# %%
# Set the model to evaluation mode
model.eval()

idx_to_word = {idx: word for word, idx in word_to_idx.items()}

y_true = []
y_pred = []

with torch.no_grad():
    for x, y in test_loader:
        # Move the data to the device
        x = x.to(device)
        y = y.to(device)

        # Forward pass
        y_hat = model(x)

        # Get back the sentence
        x_sent = [idx_to_word[i] for i in x.cpu().numpy().flatten().tolist()]

        # Compute the predicted tags
        y_pred += [idx_to_tag[i] for i in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

        # Compute the true tags
        y_true += [idx_to_tag[i] for i in y.cpu().numpy().flatten().tolist()]
        print("Sentence\t:", end = ' ')
        for i in range(len(x_sent)):
          print(x_sent[i], end = ' ')
        print("\nPredicted tags\t:", end = ' ')
        for i in range(len(y_pred)):
          print(y_pred[i], end = ' ')
        break
# Out:
# Sentence	: उनकी विशेषताओं आंदोलनों और खेल शैली के कारण उनकी तुलना वाल्टर ज़ेंगा से की गई है। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> एथन काट्ज़ ( जन्म १९८३ ) शिकागो व्हाइट सोक्स के लिए पिचिंग कोच <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> वह प्रसिद्ध रैंडविक रेसकोर्स ट्रेनर इसहाक अर्नशॉ के लिए प्रेरित था और उस समय के कुछ बेहतरीन घोड़ों के लिए सवार था। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> चेल्सी ने उथल -पुथल में मैच में प्रवेश किया उनके प्रबंधक टॉमी डोचेर्टी एक दिन पहले इस्तीफा दे दिया। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> शूप २००४ में मुख्य कोच जॉन ग्रुडेन के तहत बुक्स के लिए क्वार्टरबैक कोच था। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> उनकी प्रतिभा को शुरू में ओटो रेहगेल द्वारा नजरअंदाज कर दिया गया था लेकिन २००७ में निर्वाचक ने उन्हें कैप किया। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> क्रिस्लर ने याद किया कि वह एक नए व्यक्ति के रूप में फुटबॉल के मैदान पर भटक गया जहां उसने पौराणिक कोच अमोस अलोंजो स्टैग एक अभ्यास सत्र का निर्देशन बोस्को एंटीक लड़कों ने एनटी ने सीजन के दूसरे भाग को एक सकारात्मक नोट में शुरू किया अपने पहले तीन जुड़नार में से केवल दो अंक जीते। <PAD> <PAD> <PAD> लॉस एंजेलिस रैम्स : हैम्पटन जॉन पूल को सिडनी गिलमैन द्वारा प्रतिस्थापित किया गया था। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> टीम ने मुख्य कोच विलियम एल एलेन के तहत एक स्वतंत्र के रूप में प्रतिस्पर्धा की और ४ - ० - १ का रिकॉर्ड संकलित किया। <PAD> <PAD> <PAD> <PAD>
# Predicted tags	: O O O O O O O O O O O B-Medication/Vaccine O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O B-SportsGRP I-SportsGRP I-SportsGRP O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O B-Artist I-Artist I-Artist O O O O O O O O O O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O O O O O O O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O B-Politician I-Cleric O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O B-OtherPER I-OtherPER O O O O O O O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O <PAD> <PAD> <PAD> B-Artist I-Artist O O O O O O O I-Politician O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O B-Athlete I-Athlete I-Athlete O O O O O O O O O O O O O O O O O O O <PAD> <PAD> <PAD> <PAD>

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/DeepLearning/multiconer2023/HI-Hindi/Hindi_fine.pth')

# %%
hindi_model = model.load_state_dict(torch.load('/content/drive/MyDrive/DeepLearning/multiconer2023/HI-Hindi/Hindi_fine.pth'))

def pred_NER(sentence):
    # Split the sentence into words
    words = sentence.split()
    for word in words:
      word = word.lower()

    # Get the index of the words
    X = []
    for word in words:
        if word not in word_to_idx:
            X.append(word_to_idx["<UNK>"])
        else:
            X.append(word_to_idx[word])
    
    # Create a tensor
    X = torch.tensor(X).unsqueeze(0)
    
    # Get the predictions
    y_hat = model(X)
    
    # Get the predictions
    predictions = [idx_to_tag[pred] for pred in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

    # Give new sentence
    new_sentence = []
    flag = False
    tag = ""
    for word, pred in zip(words, predictions):
        if pred == "O":
            if flag:
                new_sentence[new_sentence.__len__() - 1] = new_sentence[new_sentence.__len__() - 1] + "[" + tag + "]"
                flag = False
                tag = ""
            new_sentence.append(word)
        elif len(pred) == 0:
            new_sentence.append(word)
        elif pred[0] == "B":
            flag = True
            tag = pred[2:]
            new_sentence.append(word)
        else:
            new_sentence.append(word)
    if flag:
        new_sentence[new_sentence.__len__() - 1] = new_sentence[new_sentence.__len__() - 1] + "[" + tag + "]"
        flag = False
        tag = "" 
    
    return " ".join(new_sentence)
print(pred_NER("जिम ने 2022 में एक्मे कॉर्प के 300 शेयर खरीदे।"))
# Out:
# जिम ने 2022[Facility] में एक्मे कॉर्प के 300 शेयर खरीदे।
