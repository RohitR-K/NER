# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install pytorch-lightning -q -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 KB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.7 MB/s eta 0:00:00

# %%
# Preprocess the Penn Treebank dataset
# Load the dataset
import torch

def read_data(file_path):
    parsed_data = []
    with open(file_path, 'r', encoding='utf-8') as f:
      parsed_tokens = []
      for line in f:
            if line == '\n' or line[0] == '#':
                if parsed_tokens:
                  parsed_data.append(parsed_tokens)
                parsed_tokens = []
            else:
                parts = line.strip().split(' _ _ ')
                word = parts[0]
                tag = parts[1] if len(parts) > 1 else ''
                parsed_tokens.append((word, tag))
    return parsed_data

train_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/BN-Bangla/bn_train.conll')
dev_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/BN-Bangla/bn_dev.conll')
test_dataset= read_data('/content/drive/MyDrive/DeepLearning/multiconer2023/BN-Bangla/bn_test.conll')

for i in range(100):
    print(train_dataset[i])
# Out:
# [('স্টেশনটি', 'O'), ('প্ল্যাটফর্ম', 'B-OtherPROD'), ('স্ক্রিন', 'I-OtherPROD'), ('ডোর', 'I-OtherPROD'), ('দিয়ে', 'O'), ('সজ্জিত।', 'O')]
# [('উদ্ভিদটির', 'O'), ('৯০', 'O'), ('০০০', 'O'), ('এরও', 'O'), ('বেশি', 'O'), ('সৌর', 'B-OtherPROD'), ('প্যানেল', 'I-OtherPROD'), ('২৩৫', 'O'), ('একরও', 'O'), ('বেশি', 'O'), ('রয়েছে।', 'O')]
# [('এই', 'O'), ('মিশনটি', 'O'), ('চন্দ্র', 'B-OtherPROD'), ('এক্স-রশ্মি', 'I-OtherPROD'), ('মানমন্দির', 'I-OtherPROD'), ('মোতায়েন', 'O'), ('করেছে।', 'O')]
# [('সংস্থাটি', 'O'), ('বেশ', 'O'), ('কয়েকটি', 'O'), ('বিমান', 'O'), ('এবং', 'O'), ('রাডার', 'B-OtherPROD'), ('স্কোয়াড্রনগুলিতে', 'O'), ('কমান্ড', 'O'), ('এবং', 'O'), ('নিয়ন্ত্রণ', 'O'), ('সরবরাহ', 'O'), ('করেছে।', 'O')]
# [('ট্রাম', 'B-OtherPROD'), ('স্টেশনটি', 'O'), ('কোচি', 'B-HumanSettlement'), ('কোওচি', 'B-ORG'), ('প্রশাসনিক', 'I-ORG'), ('অঞ্চল', 'I-ORG'), ('সূর্য', 'B-HumanSettlement'), ('উদয়ের', 'I-HumanSettlement'), ('দেশ', 'I-HumanSettlement'), ('।', 'O')]
# [('একটি', 'O'), ('কোয়ান্টাম', 'B-OtherPROD'), ('পরিগণনা', 'I-OtherPROD'), ('এমন', 'O'), ('একটি', 'O'), ('ডিভাইস', 'O'), ('যা', 'O'), ('গণনার', 'O'), ('জন্য', 'O'), ('কোয়ান্টাম', 'O'), ('প্রক্রিয়া', 'O'), ('ব্যবহার', 'O'), ('করে।', 'O')]
# [('এটি', 'O'), ('৭.৬২×৫১মিমি', 'B-OtherPROD'), ('ন্যাটো', 'I-OtherPROD'), ('কার্তুজ', 'O'), ('ব্যবহার', 'O'), ('করে', 'O'), ('তবে', 'O'), ('ব্যারেল', 'O'), ('বৈকল্পিকের', 'O'), ('উপর', 'O'), ('নির্ভর', 'O'), ('করে', 'O'), ('অন্যান্য', 'O'), ('বেশ', 'O'), ('কয়েকটি', 'O'), ('কার্তুজের', 'O'), ('জন্যও', 'O'), ('চেম্বার', 'O'), ('করা', 'O'), ('যেতে', 'O'), ('পারে।', 'O')]
# [('সুপারসোনিক', 'O'), ('প্ল্যাটফর্মে', 'O'), ('একই', 'O'), ('বৈধতা', 'O'), ('দেওয়ার', 'O'), ('জন্য', 'O'), ('মোডগুলি', 'O'), ('একটি', 'O'), ('ব্যবসায়িক', 'O'), ('জেট', 'O'), ('বোর্ডে', 'O'), ('বৈধ', 'O'), ('করা', 'O'), ('হয়েছে', 'O'), ('এবং', 'O'), ('আরও', 'O'), ('প্রুফিং', 'O'), ('হাল', 'B-OtherPROD'), ('তেজস', 'I-OtherPROD'), ('এ', 'O'), ('করা', 'O'), ('হচ্ছে।', 'O')]
# [('সমালোচকরা', 'O'), ('নীতিটিকে', 'O'), ('প্রতিরক্ষামূলক', 'O'), ('হিসাবে', 'O'), ('দেখেন', 'O'), ('এবং', 'O'), ('বড়', 'O'), ('ব্যাংক', 'O'), ('বা', 'O'), ('অন্যান্য', 'O'), ('প্রতিষ্ঠানগুলি', 'O'), ('যদি', 'O'), ('তাদের', 'O'), ('ঝুঁকি', 'B-OtherPROD'), ('ব্যবস্থাপনা', 'I-OtherPROD'), ('কার্যকর', 'O'), ('না', 'O'), ('হয়', 'O'), ('তবে', 'O'), ('ব্যর্থ', 'O'), ('হতে', 'O'), ('হবে।', 'O')]
# [('দুজনের', 'O'), ('মধ্যে', 'O'), ('একটি', 'O'), ('ইমেলের', 'O'), ('মধ্যে', 'O'), ('তারা', 'O'), ('অস্ত্রের', 'O'), ('বিনিময়', 'O'), ('হার', 'O'), ('এবং', 'O'), ('দামগুলি', 'O'), ('নিয়ে', 'O'), ('আলোচনা', 'O'), ('করেছে', 'O'), ('বিশেষত', 'O'), ('একটি', 'O'), ('এম৬০', 'B-OtherPROD'), ('।', 'O')]
# [('অন্যান্য', 'O'), ('ভাড়াটেদের', 'O'), ('মধ্যে', 'O'), ('ইন্টারন্যাশনাল', 'B-OtherPROD'), ('বিজনেস', 'I-OtherPROD'), ('মেশিন', 'I-OtherPROD'), ('কোং', 'I-OtherPROD'), ('সহায়ক', 'O'), ('সংস্থা', 'O'), ('রেড', 'B-PublicCorp'), ('হ্যাট', 'I-PublicCorp'), ('আইন', 'O'), ('সংস্থাগুলি', 'O'), ('এবং', 'O'), ('আর্থিক', 'O'), ('সংস্থাগুলি', 'O'), ('অন্তর্ভুক্ত', 'O'), ('রয়েছে।', 'O')]
# [('ইন্টেল', 'B-PublicCorp'), ('কর্পোরেশন', 'I-PublicCorp'), ('৪', 'O'), ('বিট', 'O'), ('প্রসেসর', 'O'), ('ইন্টেল', 'B-OtherPROD'), ('৪০০৪', 'I-OtherPROD'), ('মেমরি', 'O'), ('স্ট্যাকের', 'O'), ('চেয়ে', 'O'), ('অভ্যন্তরীণ', 'O'), ('স্ট্যাক', 'O'), ('প্রয়োগ', 'O'), ('করে।', 'O'), (')', 'O')]
# [('ঘন', 'O'), ('কুয়াশা', 'O'), ('এই', 'O'), ('অঞ্চলটি', 'O'), ('কম্বল', 'O'), ('করে', 'O'), ('এবং', 'O'), ('তার', 'O'), ('অন্ধ', 'O'), ('ছেড়ে', 'O'), ('চলে', 'O'), ('গেছে', 'O'), ('যখন', 'O'), ('তার', 'O'), ('রাডার', 'B-OtherPROD'), ('কমিশনের', 'O'), ('বাইরে', 'O'), ('ছিল।', 'O')]
# [('অ্যাপল', 'B-PublicCorp'), ('থেকে', 'O'), ('ম্যাকবুক', 'B-OtherPROD'), ('প্রো', 'I-OtherPROD'), ('এর', 'O'), ('অনুরূপ', 'O'), ('নকশার', 'O'), ('সাথে', 'O'), ('এটি', 'O'), ('একটি', 'O'), ('লিনাক্স', 'B-Software'), ('অপারেটিং', 'O'), ('সিস্টেমটি', 'O'), ('ডিফল্টরূপে', 'O'), ('বহন', 'O'), ('করবে।', 'O')]
# [('আইপ্যাড', 'B-OtherPROD'), ('এই', 'O'), ('প্রবণতার', 'O'), ('সর্বাধিক', 'O'), ('সুস্পষ্ট', 'O'), ('উদাহরণ', 'O'), ('তবে', 'O'), ('মোবাইল', 'O'), ('ফোনগুলিও', 'O'), ('ই', 'O'), ('রিডিং', 'O'), ('সফ্টওয়্যার', 'O'), ('হোস্ট', 'O'), ('করতে', 'O'), ('পারে।', 'O')]
# [('মিমবর', 'B-OtherPROD'), ('এর', 'O'), ('ক্ষেত্রটি', 'O'), ('৩', 'O'), ('×', 'O'), ('১', 'O'), ('.', 'O'), ('৩৮', 'O'), ('মিটার', 'O'), ('রয়েছে।', 'O')]
# [('জ্বলন্ত', 'O'), ('উপর', 'O'), ('একটি', 'O'), ('প্রকরণ', 'O'), ("হ'ল", 'O'), ('ইথানল', 'B-Medication/Vaccine'), ('এর', 'O'), ('৭০', 'O'), ('%', 'O'), ('বা', 'O'), ('আরও', 'O'), ('বেশি', 'O'), ('ঘন', 'O'), ('দ্রবণে', 'O'), ('অবজেক্টটি', 'O'), ('ডুবানো', 'O'), ('তারপরে', 'O'), ('সংক্ষিপ্তভাবে', 'O'), ('একটি', 'O'), ('বুনসেন', 'B-OtherPROD'), ('বার্নার', 'I-OtherPROD'), ('শিখায়', 'O'), ('বস্তুটি', 'O'), ('স্পর্শ', 'O'), ('করুন।', 'O')]
# [('স্ট্র্যাপ', 'O'), ('একটি', 'O'), ('হাতবন্দুক', 'B-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('একটি', 'O'), ('কথোপকথন', 'O'), ('শব্দ', 'O')]
# [('তিনি', 'O'), ('কর্মীদের', 'O'), ('দ্বারা', 'O'), ('কুস্তিগীর', 'O'), ('না', 'O'), ('হওয়া', 'O'), ('পর্যন্ত', 'O'), ('তিনি', 'O'), ('রান্নাঘরের', 'B-OtherPROD'), ('ছুরি', 'I-OtherPROD'), ('দিয়ে', 'O'), ('শিক্ষার্থী', 'O'), ('এবং', 'O'), ('শিক্ষকদের', 'O'), ('আক্রমণ', 'O'), ('করতে', 'O'), ('শুরু', 'O'), ('করেছিলেন।', 'O')]
# [('সাইটটি', 'O'), ('প্রাথমিকভাবে', 'O'), ('দুটি', 'O'), ('ফ্যালকন', 'B-OtherPROD'), ('হেভি', 'I-OtherPROD'), ('লঞ্চ', 'O'), ('সহ', 'O'), ('প্রতি', 'O'), ('বছর', 'O'), ('১২', 'O'), ('টি', 'O'), ('বাণিজ্যিক', 'O'), ('লঞ্চ', 'O'), ('সমর্থন', 'O'), ('করবে।', 'O')]
# [('কক্ষপথ', 'O'), ('থেকে', 'O'), ('কার্গো', 'O'), ('নামিয়ে', 'O'), ('আনতে', 'O'), ('সক্ষম', 'O'), ('কেবলমাত্র', 'O'), ('অন্যান্য', 'O'), ('পুনরায়', 'O'), ('সাপ্লাই', 'O'), ('মহাকাশযান', 'O'), ("হ'ল", 'O'), ('স্পেস', 'B-AerospaceManufacturer'), ('এক্স', 'I-AerospaceManufacturer'), ('স্পেস', 'B-OtherPROD'), ('এক্স', 'I-OtherPROD'), ('ড্রাগন', 'I-OtherPROD'), ('২', 'I-OtherPROD'), ('কার্গো', 'O'), ('মহাকাশযান।', 'O')]
# [('ওয়েস্টল্যান্ড', 'O'), ('এবং', 'O'), ('ইন্টারন্যাশনাল', 'B-OtherPROD'), ('বিজনেস', 'I-OtherPROD'), ('মেশিন', 'I-OtherPROD'), ('কোং', 'I-OtherPROD'), ('হেলিকপ্টারটির', 'O'), ('জটিল', 'O'), ('সিস্টেমগুলি', 'O'), ('সংহতকরণ', 'O'), ('সম্পাদনের', 'O'), ('জন্য', 'O'), ('১৯৯১', 'O'), ('সালে', 'O'), ('একটি', 'O'), ('কনসোর্টিয়াম', 'O'), ('গঠন', 'O'), ('করেছিল।', 'O')]
# [('র\u200c্যামজেটগুলি', 'O'), ('উচ্চ', 'O'), ('গতির', 'O'), ('ব্যবহারের', 'O'), ('জন্য', 'O'), ('একটি', 'O'), ('ছোট', 'O'), ('এবং', 'O'), ('সাধারণ', 'O'), ('প্রক্রিয়া', 'O'), ('যেমন', 'O'), ('ক্ষেপণাস্ত্র', 'B-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('প্রয়োজনীয়', 'O'), ('অ্যাপ্লিকেশনগুলিতে', 'O'), ('বিশেষভাবে', 'O'), ('কার্যকর', 'O'), ('হতে', 'O'), ('পারে।', 'O')]
# [('দিনের', 'O'), ('জন্য', 'O'), ('শিল্প', 'O'), ('সুবিধার', 'O'), ('একটি', 'O'), ('রাষ্ট্র', 'O'), ('উদ্ভিদটি', 'O'), ('তাত্ক্ষণিকভাবে', 'O'), ('সামরিক', 'O'), ('এবং', 'O'), ('বেসামরিক', 'O'), ('প্রশিক্ষণের', 'O'), ('জন্য', 'O'), ('সম্পূর্ণ', 'O'), ('বিমান', 'B-OtherPROD'), ('শুরু', 'O'), ('করে।', 'O')]
# [('সাপগুলি', 'O'), ('অসংখ্য', 'O'), ('নয়', 'O'), ('তবে', 'O'), ('বেশ', 'O'), ('কয়েকটি', 'O'), ('প্রজাতি', 'O'), ('প্রাণিজ', 'B-OtherPROD'), ('বিষ', 'I-OtherPROD'), ('।', 'O')]
# [('এটির', 'O'), ('প্লেস্টেশন', 'B-OtherPROD'), ('৪', 'I-OtherPROD'), ('তে', 'O'), ('কিছুটা', 'O'), ('কম', 'O'), ('স্কোর', 'O'), ('রয়েছে।', 'O')]
# [('মাইক্রোকন্ট্রোলার', 'B-OtherPROD'), ('৬৮০০০', 'O'), ('পরিবার', 'O'), ('থেকে', 'O'), ('প্রাপ্ত', 'O'), ('বিভিন্ন', 'O'), ('ধরণের', 'O'), ('অ্যাপ্লিকেশনগুলিতে', 'O'), ('ব্যবহৃত', 'O'), ('হয়েছে।', 'O')]
# [('ইন্সট্রুমেন্টেশন', 'B-OtherPROD'), ('গিটার', 'O'), ('স্ট্রিং', 'O'), ('পিয়ানো', 'O'), ('লাইন', 'O'), ('এবং', 'O'), ('ভোকাল', 'O'), ('অন্তর্ভুক্ত।', 'O')]
# [('কাজের', 'O'), ('বেঞ্চ', 'O'), ('এবং', 'O'), ('মেশিনগুলি', 'O'), ('ছাড়াও', 'O'), ('একটি', 'O'), ('সম্পূর্ণ', 'O'), ('কার্যকরী', 'O'), ('মেকানিক', 'O'), ('বুনন', 'O'), ('তাঁত', 'B-OtherPROD'), ('প্রদর্শিত', 'O'), ('হয়।', 'O')]
# [('অনেক', 'O'), ('সাপ', 'O'), ('খামারগুলি', 'O'), ('চিকিত্সা', 'O'), ('এবং', 'O'), ('বৈজ্ঞানিক', 'O'), ('গবেষণার', 'O'), ('জন্য', 'O'), ('প্রাণিজ', 'B-OtherPROD'), ('বিষ', 'I-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('দুধ', 'O'), ('সাপ।', 'O')]
# [('গানে', 'O'), ('একটি', 'O'), ('হার্ড', 'O'), ('বিকৃত', 'O'), ('ইলেকট্রিক', 'B-OtherPROD'), ('গিটার', 'I-OtherPROD'), ('বৈশিষ্ট্যযুক্ত।', 'O')]
# [('এটি', 'O'), ('এর', 'O'), ('ইতিবাচক', 'O'), ('ইনপুটটিতে', 'O'), ('একটি', 'O'), ('ইনপুট', 'O'), ('ভোল্টেজ', 'O'), ('সহ', 'O'), ('একটি', 'O'), ('সক্রিয়', 'B-OtherPROD'), ('বিবর্ধক', 'I-OtherPROD'), ('থেকে', 'O'), ('তৈরি', 'O'), ('করা', 'O'), ('যেতে', 'O'), ('পারে।', 'O')]
# [('তারা', 'O'), ('তাঁর', 'O'), ('কাছে', 'O'), ('যাওয়ার', 'O'), ('সাথে', 'O'), ('সাথে', 'O'), ('তারা', 'O'), ('একটি', 'O'), ('ভাল', 'O'), ('গোপন', 'O'), ('শত্রু', 'O'), ('বন্দুক', 'B-OtherPROD'), ('থেকে', 'O'), ('আগুনে', 'O'), ('আঘাত', 'O'), ('পেয়েছিল।', 'O')]
# [('তাঁর', 'O'), ('হেডস্টোন', 'O'), ('তার', 'O'), ('উপাধি', 'O'), ('(', 'O'), ('হোলি', 'O'), (')', 'O'), ('এর', 'O'), ('সঠিক', 'O'), ('বানান', 'O'), ('এবং', 'O'), ('তার', 'O'), ('ফেন্ডার', 'B-OtherPROD'), ('স্ট্রাটোকাস্টার', 'I-OtherPROD'), ('গিটারের', 'O'), ('একটি', 'O'), ('খোদাই', 'O'), ('বহন', 'O'), ('করে।', 'O')]
# [('ইউনাইটেড', 'O'), ('কমান্ড', 'O'), (':', 'O'), ('স্কাইটাউন', 'O'), ('(', 'O'), ('মহাকাশ', 'B-OtherPROD'), ('স্টেশন', 'I-OtherPROD'), (')', 'O'), ('মার্কিন', 'O'), ('যুক্তরাষ্ট্র।', 'O'), ('হেলিওস', 'O'), ('আরএ', 'O'), ('(', 'O'), ('প্রোব', 'O'), (')', 'O'), ('শিকাগো', 'O'), ('(', 'O'), ('কার্গো', 'O'), ('শিপ', 'O'), (')', 'O')]
# [('পে', 'O'), ('-লোড', 'O'), ('ফেয়ারিং', 'O'), ('ডাইমেনশনগুলি', 'O'), ('(', 'O'), ('সাধারণত', 'O'), ('প্রস্থ', 'O'), ('তবে', 'O'), ('উচ্চতা', 'O'), (')', 'O'), ('আধুনিক', 'O'), ('উৎক্ষেপক', 'B-OtherPROD'), ('যান', 'I-OtherPROD'), ('স্থানের', 'O'), ('মধ্যে', 'O'), ('চালু', 'O'), ('হওয়া', 'O'), ('অনমনীয়', 'O'), ('উপাদানগুলির', 'O'), ('আকারকে', 'O'), ('সীমাবদ্ধ', 'O'), ('করুন।', 'O')]
# [('তিনি', 'O'), ('৫২', 'O'), ('এর', 'O'), ('জন্য', 'O'), ('দুটি', 'O'), ('সেরা', 'O'), ('বিশ্লেষণ', 'O'), ('সহ', 'O'), ('তিনটি', 'O'), ('উইকেট', 'B-OtherPROD'), ('নিয়েছিলেন।', 'O')]
# [('শাকসব্জী', 'O'), ('এবং', 'O'), ('ফলের', 'O'), ('খোসা', 'O'), ('ছাড়ানোর', 'O'), ('বিকল্প', 'O'), ('উপায়', 'O'), ("হ'ল", 'O'), ('একটি', 'O'), ('পিলার', 'B-OtherPROD'), ('ব্যবহার', 'O'), ('করা।', 'O')]
# [('গ্লোবাল', 'O'), ('বৈদ্যুতিক', 'B-OtherPROD'), ('যানবাহন', 'I-OtherPROD'), ('পুশ', 'O'), ('বিশ্বজুড়ে', 'O'), ('সমস্ত', 'O'), ('বৈদ্যুতিক', 'O'), ('টার্মিনাল', 'O'), ('ট্রাক', 'O'), ('প্রস্তুতকারকদের', 'O'), ('প্রচুর', 'O'), ('পরিমাণে', 'O'), ('জন্ম', 'O'), ('দিয়েছে।', 'O')]
# [('অনেক', 'O'), ('দ্রুত', 'O'), ('গুণক', 'O'), ('স্ট্যাটিক', 'O'), ('সিমস', 'B-OtherPROD'), ('এ', 'O'), ('প্রয়োগ', 'O'), ('করা', 'O'), ('কমপ্রেসার', 'O'), ('হিসাবে', 'O'), ('সম্পূর্ণ', 'O'), ('অ্যাডার', 'O'), ('ব্যবহার', 'O'), ('করে', 'O'), ('(', 'O'), ('৩', 'O'), (':', 'O'), ('২', 'O'), ('কমপ্রেসর', 'O'), (')', 'O'), ('।', 'O')]
# [('সরবরাহ', 'B-OtherPROD'), ('শৃঙ্খল', 'I-OtherPROD'), ('ব্যবস্থাপনা', 'I-OtherPROD'), ('কী', 'O'), ('এবং', 'O'), ('আধুনিক', 'O'), ('ব্যবসায়িক', 'O'), ('অনুশীলনে', 'O'), ('এর', 'O'), ('কার্যকারিতা', 'O'), ('সম্পর্কে', 'O'), ('সচেতনতা', 'O'), ('এবং', 'O'), ('বোঝার', 'O'), ('জন্য', 'O'), ('একটি', 'O'), ('সমন্বিত', 'O'), ('প্রচেষ্টা।', 'O')]
# [('তারা', 'O'), ('১৯৫৩', 'O'), ('সালে', 'O'), ('র\u200d্যামজেট', 'B-OtherPROD'), ('শক্তি', 'O'), ('শুরু', 'O'), ('করে', 'O'), ('ব্যবহার', 'O'), ('করে', 'O'), ('ডিজাইনের', 'O'), ('একটি', 'O'), ('সিরিজ', 'O'), ('বিবেচনা', 'O'), ('করেছিল।', 'O')]
# [('যখন', 'O'), ('নিমজ্জিত', 'O'), ('হয়', 'O'), ('প্রতিটি', 'O'), ('প্রোপেলার', 'O'), ('একটি', 'O'), ('বৈদ্যুতিক', 'B-OtherPROD'), ('মোটর', 'I-OtherPROD'), ('দ্বারা', 'O'), ('চালিত', 'O'), ('হয়েছিল।', 'O')]
# [('তিনি', 'O'), ('৮', 'O'), ('এর', 'O'), ('জন্য', 'O'), ('পাঁচটি', 'O'), ('সেরা', 'O'), ('বিশ্লেষণ', 'O'), ('সহ', 'O'), ('২৮', 'O'), ('উইকেট', 'B-OtherPROD'), ('নিয়েছেন।', 'O')]
# [('কীবোর্ডটি', 'O'), ('আইফোন', 'B-OtherPROD'), ('এবং', 'O'), ('আইপ্যাড', 'B-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('উপলব্ধ', 'O'), ('এবং', 'O'), ('গুগল', 'B-PublicCorp'), ('দ্বারা', 'O'), ('সমর্থিত।', 'O')]
# [('এই', 'O'), ('উপসংহারটি', 'O'), ('১৯৭৪', 'O'), ('সালে', 'O'), ('নিশ্চিত', 'O'), ('হয়েছিল', 'O'), ('যখন', 'O'), ('মানহীন', 'O'), ('মেরিনার', 'B-OtherPROD'), ('১০', 'I-OtherPROD'), ('স্পেসপ্রোব', 'O'), ('কেবল', 'O'), ('একটি', 'O'), ('সুস্পষ্ট', 'O'), ('এক্সোস্ফিয়ার', 'O'), ('আবিষ্কার', 'O'), ('করেছিল।', 'O')]
# [('প্লাটজি', 'O'), ('মাইক্রোসফট', 'B-PublicCorp'), ('কর্পোরেশন', 'I-PublicCorp'), ('ইন্টারন্যাশনাল', 'B-OtherPROD'), ('বিজনেস', 'I-OtherPROD'), ('মেশিন', 'I-OtherPROD'), ('কোং', 'I-OtherPROD'), ('facebook', 'B-Software'), ('এবং', 'O'), ('গুগল', 'B-PublicCorp'), ('সহ', 'O'), ('কর্পোরেশনগুলির', 'O'), ('জন্য', 'O'), ('কর্মচারী', 'O'), ('প্রশিক্ষণ', 'O'), ('কোর্সও', 'O'), ('তৈরি', 'O'), ('করেছেন।', 'O')]
# [('ট্রেটি', 'O'), ('তখন', 'O'), ('ক্লায়েন্টকে', 'O'), ('পরিবেশন', 'O'), ('না', 'O'), ('করা', 'O'), ('পর্যন্ত', 'O'), ('এর', 'O'), ('সামগ্রীগুলি', 'O'), ('গরম', 'O'), ('রাখতে', 'O'), ('একটি', 'O'), ('তন্দুর', 'B-OtherPROD'), ('এর', 'O'), ('সরাসরি', 'O'), ('একটি', 'O'), ('বড়', 'O'), ('ক্রিস্পি', 'O'), ('ফ্ল্যাটব্রেড', 'O'), ('দ্বারা', 'O'), ('আচ্ছাদিত', 'O'), ('করা', 'O'), ('হয়।', 'O')]
# [('গেমটি', 'O'), ('২০১০', 'O'), ('সালে', 'O'), ('আইওএস', 'B-Software'), ('প্লেস্টেশন', 'B-OtherPROD'), ('৩', 'I-OtherPROD'), ('এবং', 'O'), ('এক্সবক্স', 'B-OtherPROD'), ('৩৬০', 'I-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('প্রকাশিত', 'O'), ('হয়েছিল।', 'O')]
# [('এছাড়াও', 'O'), ('প্লেস্টেশন', 'B-OtherPROD'), ('২', 'I-OtherPROD'), ('এ', 'O'), ('প্রকাশিত', 'O'), ('দুটি', 'O'), ('স্পিন', 'O'), ('অফ', 'O'), ('গেমগুলির', 'O'), ('সাথে', 'O'), ('দুটি', 'O'), ('সিক্যুয়াল', 'O'), ('এটি', 'O'), ('অনুসরণ', 'O'), ('করেছে।', 'O')]
# [('এখানে', 'O'), ('সমস্ত', 'O'), ('প্ল্যানেট', 'O'), ('লাইট', 'O'), ('মাউন্টগুলিতে', 'O'), ('রয়েছে', 'O'), ('যা', 'O'), ('কেবল', 'O'), ('কেন্দ্রীয়', 'O'), ('অক্ষ', 'O'), ('সম্পর্কে', 'O'), ('ঘোরান', 'O'), ('এবং', 'O'), ('এটি', 'O'), ('একটি', 'O'), ('কম্পিউটার', 'B-OtherPROD'), ('দ্বারা', 'O'), ('লক্ষ্য', 'O'), ('করা', 'O'), ('হয়।', 'O')]
# [('লাল', 'B-OtherPROD'), ('গালিচা', 'I-OtherPROD'), ('স্থাপন', 'O'), ('করতে', 'O'), ('বা', 'O'), ('রেড', 'O'), ('কার্পেট', 'O'), ('চিকিত্সা', 'O'), ('দেওয়ার', 'O'), ('জন্য', 'O'), ('(', 'O'), ('কাউকে', 'O'), ('রয়্যালকে', 'O'), ('খুব', 'O'), ('বিশেষ', 'O'), ('ব্যক্তি', 'O'), ('হিসাবে', 'O'), ('বিবেচনা', 'O'), ('করা', 'O'), (')', 'O')]
# [('মাইক্রোসফট', 'B-Software'), ('উইন্ডোজ', 'I-Software'), ('ওএস', 'B-Software'), ('এক্স', 'I-Software'), ('প্লেস্টেশন', 'B-OtherPROD'), ('৪', 'I-OtherPROD'), ('এক্সবক্স', 'B-OtherPROD'), ('ওয়ান', 'I-OtherPROD'), ('আইওএস', 'B-Software'), ('অ্যান্ড্রয়েড', 'B-Software'), ('(অপারেটিং', 'I-Software'), ('সিস্টেম)', 'I-Software')]
# [('ভয়েস', 'B-Software'), ('ওভার', 'I-Software'), ('ইন্টারনেট', 'I-Software'), ('প্রোটোকল', 'I-Software'), ('প্রযুক্তি', 'O'), ('skype', 'B-Software'), ('এর', 'O'), ('মতো', 'O'), ('একটি', 'O'), ('পরিষেবা', 'O'), ('ব্যবহার', 'O'), ('করে', 'O'), ('একটি', 'O'), ('ব্যক্তিগত', 'B-OtherPROD'), ('কম্পিউটার', 'I-OtherPROD'), ('এর', 'O'), ('মাধ্যমে', 'O'), ('কলগুলি', 'O'), ('তৈরি', 'O'), ('করার', 'O'), ('অনুমতি', 'O'), ('দেয়।', 'O')]
# [('এই', 'O'), ('প্রতিসরণ', 'B-OtherPROD'), ('দূরবিন', 'I-OtherPROD'), ('কোনও', 'O'), ('ব্যক্তি', 'O'), ('এবং', 'O'), ('অষ্টম', 'O'), ('বৃহত্তম', 'O'), ('রিফ্র্যাক্টর', 'O'), ('দ্বারা', 'O'), ('নির্মিত', 'O'), ('এখন', 'O'), ('পর্যন্ত', 'O'), ('নির্মিত', 'O'), ('বৃহত্তম।', 'O')]
# [('রাতে', 'O'), ('বোম্বারটি', 'O'), ('কার্যত', 'O'), ('অদম্য', 'O'), ('(', 'O'), ('রাডার', 'B-OtherPROD'), ('এর', 'O'), ('প্রবর্তন', 'O'), ('না', 'O'), ('হওয়া', 'O'), ('পর্যন্ত', 'O'), (')', 'O'), ('তবে', 'O'), ('এর', 'O'), ('লক্ষ্য', 'O'), ('খুঁজে', 'O'), ('পাওয়া', 'O'), ('একটি', 'O'), ('বড়', 'O'), ('সমস্যা', 'O'), ('ছিল।', 'O')]
# [('ভারী', 'O'), ('সশস্ত্র', 'O'), ('আর্মার্ড', 'B-OtherPROD'), ('পার্সোনেল', 'I-OtherPROD'), ('ক্যারিয়ার', 'I-OtherPROD'), ('হিসাবে', 'O'), ('তাদের', 'O'), ('গৌণ', 'O'), ('ভূমিকার', 'O'), ('কারণে', 'O'), ('সিস্টেমগুলি', 'O'), ('পরিষেবাতে', 'O'), ('থাকবে।', 'O')]
# [('এই', 'O'), ('প্রজাতিটি', 'O'), ('তার', 'O'), ('পাখার', 'O'), ('মেরুদণ্ডে', 'O'), ('প্রাণিজ', 'B-OtherPROD'), ('বিষ', 'I-OtherPROD'), ('উত্পাদন', 'O'), ('করে।', 'O')]
# [('রানওয়ের', 'O'), ('২', 'O'), ('০০০', 'O'), ('মিটারের', 'O'), ('মধ্যে', 'O'), ('কেবল', 'O'), ('৮০০', 'O'), ('মিটার', 'O'), ('এখন', 'O'), ('বিমান', 'B-OtherPROD'), ('ব্যবহারের', 'O'), ('জন্য', 'O'), ('উপলব্ধ।', 'O')]
# [('চ্যান্সেলের', 'O'), ('পাশাপাশি', 'O'), ('উত্তর', 'O'), ('আইলটির', 'O'), ('পূর্ব', 'O'), ('প্রান্তে', 'O'), ('অর্গান', 'B-OtherPROD'), ('(সঙ্গীত)', 'I-OtherPROD'), ('(', 'O'), ('এটি', 'O'), ('উপরে', 'O'), ('চিত্রিত', 'O'), ('হিসাবে', 'O'), ('এটি', 'O'), ('১৯০৭', 'O'), ('সালের', 'O'), ('মধ্যে', 'O'), ('ছিল', 'O'), (')', 'O'), ('এর', 'O'), ('জন্য', 'O'), ('একটি', 'O'), ('স্থান', 'O'), ('ছিল।', 'O')]
# [('এই', 'O'), ('রেলকারগুলি', 'O'), ('একটি', 'O'), ('ইঞ্জিন', 'B-OtherPROD'), ('দ্বারা', 'O'), ('চালিত', 'O'), ('হয়েছিল।', 'O')]
# [('ট্রাম', 'B-OtherPROD'), ('স্টেশনটি', 'O'), ('কোচি', 'B-HumanSettlement'), ('কোওচি', 'B-ORG'), ('প্রশাসনিক', 'I-ORG'), ('অঞ্চল', 'I-ORG'), ('সূর্য', 'B-HumanSettlement'), ('উদয়ের', 'I-HumanSettlement'), ('দেশ', 'I-HumanSettlement'), ('।', 'O')]
# [('টেলিগ্রাফ', 'O'), ('তারের', 'O'), ('অপারেশনের', 'O'), ('জন্য', 'O'), ('ডিজাইন', 'O'), ('করা', 'O'), ('একটি', 'O'), ('বিশেষ', 'O'), ('টাইপরাইটার', 'B-OtherPROD'), ('টিকার', 'O'), ('মেশিনের', 'O'), ('টেলিগ্রাফ', 'O'), ('তারের', 'O'), ('সংযোগের', 'O'), ('বিপরীত', 'O'), ('প্রান্তে', 'O'), ('ব্যবহৃত', 'O'), ('হয়েছিল।', 'O')]
# [('ওরায়ন', 'B-OtherPROD'), ('(মহাকাশযান)', 'I-OtherPROD'), ('এর', 'O'), ('আগের', 'O'), ('নকশা', 'O'), ('থেকে', 'O'), ('কার্যত', 'O'), ('অপরিবর্তিত', 'O'), ('রয়েছে।', 'O')]
# [('এটি', 'O'), ('অল্টেয়ার', 'B-OtherPROD'), ('৮৮০০', 'I-OtherPROD'), ('কম্পিউটারের', 'O'), ('একটি', 'O'), ('প্যারোডি', 'O'), ('ছিল', 'O'), ('যা', 'O'), ('সেই', 'O'), ('সময়ে', 'O'), ('খুব', 'O'), ('জনপ্রিয়', 'O'), ('ছিল।', 'O')]
# [('এরপরে', 'O'), ('জ্যোতির্বিজ্ঞানীদের', 'O'), ('প্রক্রিয়াজাতকরণের', 'O'), ('প্রায়', 'O'), ('এক', 'O'), ('সপ্তাহ', 'O'), ('পরে', 'O'), ('পোস্টের', 'O'), ('মাধ্যমে', 'O'), ('ম্যাগনেটিক', 'B-OtherPROD'), ('টেপ', 'I-OtherPROD'), ('এ', 'O'), ('তাদের', 'O'), ('ডেটা', 'O'), ('প্রেরণ', 'O'), ('করা', 'O'), ('হয়েছিল।', 'O')]
# [('জিফোর্স', 'B-OtherPROD'), ('৬০০০', 'O'), ('এবং', 'O'), ('আপ', 'O'), ('(', 'O'), ('এনভি', 'O'), ('৪০', 'O'), ('জিপিইউ', 'O'), ('বা', 'O'), ('তার', 'O'), ('পরে', 'O'), (')', 'O')]
# [('মল', 'O'), ('টেবিল', 'B-OtherPROD'), ('এবং', 'O'), ('রিড', 'O'), ('ম্যাটগুলিও', 'O'), ('সাধারণ', 'O'), ('ছিল।', 'O')]
# [('তাঁর', 'O'), ('একটি', 'O'), ('অর্গান', 'B-OtherPROD'), ('(সঙ্গীত)', 'I-OtherPROD'), ('ইনস্টল', 'O'), ('করা', 'O'), ('হয়েছিল।', 'O')]
# [('দুটি', 'O'), ('দুটি', 'O'), ('বর্গ', 'O'), ('মিটার', 'O'), ('সৌর', 'B-OtherPROD'), ('প্যানেল', 'I-OtherPROD'), ('রিচার্জেবল', 'O'), ('ব্যাটারি', 'O'), ('চার্জ', 'O'), ('করেছে।', 'O')]
# [('একটি', 'O'), ('সাঁজোয়া', 'O'), ('যান', 'O'), ('একটি', 'O'), ('মলটভ', 'B-OtherPROD'), ('ককটেইল', 'I-OtherPROD'), ('দ্বারা', 'O'), ('আঘাত', 'O'), ('করা', 'O'), ('হয়েছিল।', 'O')]
# [('হার্ডওয়্যার', 'O'), ('সামঞ্জস্যতার', 'O'), ('সমস্যার', 'O'), ('কারণে', 'O'), ('গেমটির', 'O'), ('ডিজিটাল', 'O'), ('সংস্করণটি', 'O'), ('এক্সবক্স', 'B-OtherPROD'), ('ওয়ান', 'I-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('উপলব্ধ', 'O'), ('ছিল।', 'O')]
# [('এই', 'O'), ('সংকেতটি', 'O'), ('সহজেই', 'O'), ('সাধারণ', 'O'), ('ইলেকট্রনিক্স', 'O'), ('দ্বারা', 'O'), ('বা', 'O'), ('মাইক্রোকন্ট্রোলার', 'B-OtherPROD'), ('যেমন', 'O'), ('অরড্যুইনো', 'B-ORG'), ('দ্বারা', 'O'), ('উত্পাদিত', 'O'), ('হয়।', 'O')]
# [('এফকে।', 'O'), ('৪২', 'O'), ('এর', 'O'), ('একটি', 'O'), ('বড়', 'O'), ('ট্র্যাক', 'O'), ('সহ', 'O'), ('লেজস্কিড', 'O'), ('ল্যান্ডিং', 'B-OtherPROD'), ('গিয়ার', 'I-OtherPROD'), ('স্থির', 'O'), ('ছিল।', 'O')]
# [('তারা', 'O'), ('যুদ্ধের', 'O'), ('ময়দানে', 'O'), ('ক্ষতিগ্রস্থদের', 'O'), ('পরিবহনের', 'O'), ('জন্য', 'O'), ('🚑', 'B-OtherPROD'), ('হিসাবে', 'O'), ('একটি', 'O'), ('ঘোড়া', 'O'), ('টানা', 'O'), ('গাড়ি', 'O'), ('ব্যবহার', 'O'), ('করার', 'O'), ('জন্য', 'O'), ('এটি', 'O'), ('তাদের', 'O'), ('এনেছিল।', 'O')]
# [('শারীরিক', 'O'), ('সম্বোধনের', 'O'), ('সীমাটি', 'O'), ('কতটা', 'O'), ('ইনস্টল', 'O'), ('করা', 'O'), ('হয়েছে', 'O'), ('র\u200c্যান্ডম', 'B-OtherPROD'), ('অ্যাক্সেস', 'I-OtherPROD'), ('মেমোরি', 'I-OtherPROD'), ('কম্পিউটার', 'O'), ('দ্বারা', 'O'), ('অ্যাক্সেস', 'O'), ('করতে', 'O'), ('সক্ষম।', 'O')]
# [('ডেস্কটপ', 'B-OtherPROD'), ('কম্পিউটার', 'I-OtherPROD'), ('একটি', 'O'), ('ডেস্কে', 'O'), ('ফিট', 'O'), ('করার', 'O'), ('জন্য', 'O'), ('ডিজাইন', 'O'), ('করা', 'O'), ('একটি', 'O'), ('ব্যক্তিগত', 'O'), ('কম্পিউটার', 'O')]
# [('পক্সভাইরাসগুলিতে', 'O'), ('সাধারণত', 'O'), ('বড়', 'O'), ('বংশাণুসমগ্র', 'B-OtherPROD'), ('থাকে', 'O'), ('এবং', 'O'), ('এই', 'O'), ('জাতীয়', 'O'), ('অন্যান্য', 'O'), ('উদাহরণগুলির', 'O'), ('মধ্যে', 'O'), ('রয়েছে', 'O'), ('গুটিবসন্ত', 'B-Disease'), ('এবং', 'O'), ('মাংকিপক্স', 'B-Disease'), ('।', 'O')]
# [('যখন', 'O'), ('নিমজ্জিত', 'O'), ('হয়', 'O'), ('প্রতিটি', 'O'), ('প্রোপেলার', 'O'), ('একটি', 'O'), ('বৈদ্যুতিক', 'B-OtherPROD'), ('মোটর', 'I-OtherPROD'), ('দ্বারা', 'O'), ('চালিত', 'O'), ('হয়েছিল।', 'O')]
# [('যান্ত্রিক', 'B-OtherPROD'), ('ক্যালকুলেটর', 'I-OtherPROD'), ('একটি', 'O'), ('পোর্টেবল', 'O'), ('বৈদ্যুতিন', 'O'), ('ডিভাইস', 'O'), ('গণনা', 'O'), ('সম্পাদন', 'O'), ('করতে', 'O'), ('ব্যবহৃত', 'O'), ('হয়', 'O')]
# [('সামরিক', 'B-OtherPROD'), ('হেলিকপ্টার', 'I-OtherPROD'), ('ট্রান্সপোর্ট', 'O'), ('হেলিকপ্টারগুলি', 'O'), ('এমন', 'O'), ('জায়গায়', 'O'), ('ব্যবহৃত', 'O'), ('হয়', 'O'), ('যেখানে', 'O'), ('প্রচলিত', 'O'), ('বিমানের', 'O'), ('ব্যবহার', 'O'), ('অসম্ভব।', 'O')]
# [('কিউইকি', 'O'), ('একটি', 'O'), ('আইফোন', 'B-OtherPROD'), ('অ্যাপ্লিকেশন', 'O'), ('প্রকাশ', 'O'), ('করেছে', 'O'), ('যা', 'O'), ('কোনও', 'O'), ('ব্যবহারকারীর', 'O'), ('ক্যামেরা', 'O'), ('রোল', 'O'), ('থেকে', 'O'), ('ছবি', 'O'), ('এবং', 'O'), ('ভিডিওগুলি', 'O'), ('স্বয়ংক্রিয়ভাবে', 'O'), ('ভাগ', 'O'), ('করে', 'O'), ('নেওয়ার', 'O'), ('জন্য', 'O'), ('মুভিগুলিতে', 'O'), ('পরিণত', 'O'), ('করে।', 'O')]
# [('গ্রিন', 'O'), ('সাপ্লাই', 'O'), ('চেইন', 'O'), ('ম্যানেজমেন্ট', 'O'), ('(', 'O'), ('জিএসসিএম', 'O'), (')', 'O'), ('সরবরাহ', 'B-OtherPROD'), ('শৃঙ্খল', 'I-OtherPROD'), ('ব্যবস্থাপনা', 'I-OtherPROD'), ('এ', 'O'), ('পরিবেশগত', 'O'), ('সমস্যাগুলির', 'O'), ('বিবেচনা।', 'O')]
# [('পোস্ট', 'O'), ('মর্টেমগুলি', 'O'), ('প্রায়শই', 'O'), ('কার্যকর', 'O'), ('ঝুঁকি', 'B-OtherPROD'), ('ব্যবস্থাপনা', 'I-OtherPROD'), ('এর', 'O'), ('চলমান', 'O'), ('পূর্ববর্তীগুলির', 'O'), ('একটি', 'O'), ('মূল', 'O'), ('উপাদান', 'O'), ('হিসাবে', 'O'), ('বিবেচিত', 'O'), ('হয়।', 'O')]
# [('ব্যবহারকারীকে', 'O'), ('১২৮', 'O'), ('গিগাবাইট', 'O'), ('সলিড-স্টেট', 'B-OtherPROD'), ('ড্রাইভ', 'I-OtherPROD'), ('পাশাপাশি', 'O'), ('স্টোরেজের', 'O'), ('জন্য', 'O'), ('বৃহত্তর', 'O'), ('২৫৬', 'O'), ('জিবি', 'O'), ('সলিড-স্টেট', 'B-OtherPROD'), ('ড্রাইভ', 'I-OtherPROD'), ('এর', 'O'), ('একটি', 'O'), ('পছন্দ', 'O'), ('দেওয়া', 'O'), ('হয়েছিল।', 'O')]
# [('গ্যালাক্সির', 'O'), ('প্রকৃত', 'O'), ('প্রকৃতির', 'O'), ('একটি', 'O'), ('রেজোলিউশন', 'O'), ('সম্ভবত', 'O'), ('জেমস', 'B-OtherPROD'), ('ওয়েব', 'I-OtherPROD'), ('মহাকাশ', 'I-OtherPROD'), ('দূরবীক্ষণ', 'I-OtherPROD'), ('যন্ত্র', 'I-OtherPROD'), ('থেকে', 'O'), ('নিশ্চিতকরণের', 'O'), ('জন্য', 'O'), ('অপেক্ষা', 'O'), ('করবে।', 'O')]
# [('এটিএন্ডটি', 'O'), ('ডিএসপি', 'O'), ('১', 'O'), ('ছিল', 'O'), ('বেল', 'B-PrivateCorp'), ('ল্যাবস্', 'I-PrivateCorp'), ('দ্বারা', 'O'), ('নির্মিত', 'O'), ('একটি', 'O'), ('অগ্রণী', 'O'), ('ডিজিটাল', 'B-OtherPROD'), ('সিগন্যাল', 'I-OtherPROD'), ('প্রসেসর', 'I-OtherPROD'), ('(', 'O'), ('ডিএসপি', 'O'), (')', 'O'), ('।', 'O')]
# [('উভয়গুলিতে', 'O'), ('পাবলিক', 'O'), ('অ্যাক্সেস', 'O'), ('হয়', 'O'), ('পায়ে', 'O'), ('হেঁটে', 'O'), ('বাইসাইকেল', 'B-OtherPROD'), ('বা', 'O'), ('নৌকা', 'O'), ('দ্বারা।', 'O')]
# [('এটি', 'O'), ('১৯৮২', 'O'), ('সালে', 'O'), ('অ্যাপল', 'B-OtherPROD'), ('২', 'I-OtherPROD'), ('এর', 'O'), ('জন্য', 'O'), ('প্রকাশিত', 'O'), ('হয়েছিল', 'O'), ('পর্যালোচকদের', 'O'), ('কাছ', 'O'), ('থেকে', 'O'), ('ইতিবাচক', 'O'), ('প্রতিক্রিয়া', 'O'), ('পেয়ে।', 'O')]
# [('বিএডাব্লু', 'O'), ('বেসামরিক', 'O'), ('পাশাপাশি', 'O'), ('সামরিক', 'B-OtherPROD'), ('যানবাহন', 'I-OtherPROD'), ('উত্পাদন', 'O'), ('করে।', 'O')]
# [('অক্টোবর', 'O'), ('২০১৭', 'O'), ('এর', 'O'), ('মাঝামাঝি', 'O'), ('সময়ে', 'O'), ('মাইক্রোসফট', 'B-PublicCorp'), ('কর্পোরেশন', 'I-PublicCorp'), ('ঘোষণা', 'O'), ('করেছে', 'O'), ('যে', 'O'), ('win10', 'B-Software'), ('কোয়ালকম', 'B-OtherPROD'), ('স্ন্যাপড্রাগন', 'I-OtherPROD'), ('এ', 'O'), ('পরীক্ষার', 'O'), ('চূড়ান্ত', 'O'), ('পর্যায়ে', 'O'), ('রয়েছে।', 'O')]
# [('একটি', 'O'), ('বন্ধনী', 'O'), ('ঘড়িটি', 'O'), ('১৭', 'O'), ('তম', 'O'), ('এবং', 'O'), ('১৮', 'O'), ('শতকে', 'O'), ('তৈরি', 'O'), ('অ্যান্টিক', 'O'), ('পোর্টেবল', 'O'), ('টেবিল', 'O'), ('ঘড়ি', 'B-OtherPROD'), ('এর', 'O'), ('একটি', 'O'), ('স্টাইল।', 'O')]
# [('জাহাজগুলি', 'O'), ('বিভিন্ন', 'O'), ('ধরণের', 'O'), ('ক্ষেপণাস্ত্র', 'B-OtherPROD'), ('পরিষেবাতে', 'O'), ('আসা', 'O'), ('বিভিন্ন', 'O'), ('ধরণের', 'O'), ('পরিষেবা', 'O'), ('দিতে', 'O'), ('সক্ষম', 'O'), ('হয়েছিল।', 'O')]
# [('বেলুন', 'O'), ('লুপগুলি', 'O'), ('একক', 'O'), ('সমাপ্ত', 'O'), ('ট্রাম', 'O'), ('সহ', 'O'), ('ট্রাম', 'B-OtherPROD'), ('সিস্টেমে', 'O'), ('ব্যাপকভাবে', 'O'), ('ব্যবহৃত', 'O'), ('হয়।', 'O')]
# [('৭৮', 'O'), ('কে', 'O'), ("হ'ল", 'O'), ('বাণিজ্যিক', 'O'), ('মার্কা', 'O'), ('১৬', 'O'), ('এবং', 'O'), ('৮', 'O'), ('বিট', 'O'), ('মাইক্রোকন্ট্রোলার', 'B-OtherPROD'), ('পরিবারের', 'O'), ('নাম', 'O')]
# [('চুক্তির', 'O'), ('অধীনে', 'O'), ('তিনটি', 'O'), ('দেশ', 'O'), ('হাইপারসনিক', 'B-OtherPROD'), ('অস্ত্র', 'I-OtherPROD'), ('এর', 'O'), ('উন্নয়নকে', 'O'), ('ত্বরান্বিত', 'O'), ('করতে', 'O'), ('এবং', 'O'), ('এই', 'O'), ('জাতীয়', 'O'), ('ক্ষেপণাস্ত্রগুলির', 'O'), ('বিরুদ্ধে', 'O'), ('প্রতিরক্ষা', 'O'), ('করার', 'O'), ('জন্য', 'O'), ('সহযোগিতা', 'O'), ('করবে।', 'O')]
# [('চিরসবুজ', 'O'), ('/', 'O'), ('৪০০', 'O'), ('এর', 'O'), ('বিশ্বব্যাপী', 'O'), ('বিতরণ', 'O'), ('ইন্টারন্যাশনাল', 'B-OtherPROD'), ('বিজনেস', 'I-OtherPROD'), ('মেশিন', 'I-OtherPROD'), ('কোং', 'I-OtherPROD')]
# [('সংস্থার', 'O'), ('ব্যবসায়িক', 'O'), ('মডেল', 'O'), ('বিলাসবহুল', 'O'), ('ভাড়ার', 'B-OtherPROD'), ('জন্য', 'I-OtherPROD'), ('যানবাহন', 'I-OtherPROD'), ('বাজারে', 'O'), ('ফোকাস', 'O'), ('করে।', 'O')]
# [('একটি', 'O'), ('কিন্ডিল', 'O'), ('একটি', 'O'), ('লণ্ঠন', 'B-OtherPROD'), ('একটি', 'O'), ('কাঠের', 'O'), ('কাঠামো', 'O'), ('সহ', 'O'), ('এবং', 'O'), ('রঙিন', 'O'), ('ম্যাট', 'O'), ('বা', 'O'), ('চকচকে', 'O'), ('কাগজপত্রগুলিতে', 'O'), ('আবৃত।', 'O')]
# [('এটি', 'O'), ('সাধারণত', 'O'), ('কেন্দ্রীয়', 'B-OtherPROD'), ('প্রক্রিয়াজাতকরণ', 'I-OtherPROD'), ('ইউনিট', 'I-OtherPROD'), ('(', 'O'), ('সিপিইউ', 'O'), (')', 'O'), ('এর', 'O'), ('অংশ', 'O'), ('হিসাবে', 'O'), ('প্রয়োগ', 'O'), ('করা', 'O'), ('হয়।', 'O')]

# %%
SEQ_LEN = 30

# Create word_to_idx and tag_to_idx mappings
word_to_idx = {"<PAD>": 0, "<UNK>": 1}
tag_to_idx = {"<PAD>": 0}


def preprocess(dataset):
    # Extract sentences and tags
    sent = [[token.lower() for token, tag in sentence] for sentence in dataset]
    tags = [[tag for token, tag in sentence] for sentence in dataset]

    for i in range(len(sent)):
        while len(sent[i]) < SEQ_LEN:
            sent[i].append('<PAD>')
            tags[i].append('<PAD>')

        if len(sent[i]) > SEQ_LEN:
            sent[i] = sent[i][:SEQ_LEN]
            tags[i] = tags[i][:SEQ_LEN]
    
    for sentence_tags in tags:
        for tag in sentence_tags:
            if tag not in tag_to_idx:
                tag_to_idx[tag] = len(tag_to_idx)
    
    for sentence in sent:
        for word in sentence:
            if word not in word_to_idx:
                word_to_idx[word] = len(word_to_idx)

    # Convert words and tags to indices
    X = torch.tensor([[word_to_idx.get(word, 1) for word in sentence] for sentence in sent], dtype=torch.int).type(torch.LongTensor)
    Y = torch.tensor([[tag_to_idx[tag] for tag in sentence] for sentence in tags], dtype=torch.int).type(torch.LongTensor)
    
    return X, Y

# %%
train_X, train_Y = preprocess(train_dataset)
dev_X, dev_Y = preprocess(dev_dataset)
test_X, test_Y = preprocess(test_dataset)

# %%
# Print the sizes of the datasets
print(f"Number of training examples: {len(train_X)}")
print(f"Number of validation examples: {len(dev_X)}")
print(f"Number of testing examples: {len(test_X)}")
# for i in range(100):
#     print(train_X[i])
# Out:
# Number of training examples: 9708
# Number of validation examples: 507
# Number of testing examples: 19859

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pytorch_lightning as pl

class NERModel(pl.LightningModule):
    def __init__(self, vocab_size, tagset_size, embedding_dim, hidden_dim, num_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim) #B * seq_len, B * seq_len * embedding_dim
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=num_layers, bidirectional=True)
        self.fc = nn.Linear(2*hidden_dim, tagset_size)
        self.loss_fn = nn.CrossEntropyLoss()
    
    def forward(self, x):
        embeds = self.embedding(x)
        #print(embeds.shape)
        lstm_out, _ = self.lstm(embeds)
        tag_space = self.fc(lstm_out)
        tag_scores = nn.functional.log_softmax(tag_space, dim=2)
        return tag_scores
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('train_loss', loss)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('val_loss', loss)
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_fn(y_hat.view(-1, y_hat.shape[-1]), y.view(-1))
        self.log('test_loss', loss)
        return loss
    
    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters())
        return optimizer

# %%
from torch.utils.data import DataLoader, TensorDataset
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

EMBEDDING_DIM = 125
HIDDEN_DIM    = 125
NUM_EPOCHS    = 10 
BATCH_SIZE    = 10

train_dataset = TensorDataset(train_X, train_Y)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

val_dataset = TensorDataset(dev_X, dev_Y)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

test_dataset = TensorDataset(test_X, test_Y)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
model = NERModel(vocab_size=len(word_to_idx), tagset_size=len(tag_to_idx), embedding_dim=EMBEDDING_DIM, hidden_dim=HIDDEN_DIM)
early_stopping = EarlyStopping(monitor="val_loss", patience=3, mode="min")
trainer = pl.Trainer(max_epochs=NUM_EPOCHS, callbacks=[early_stopping])
trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)

trainer.test(dataloaders=test_loader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | embedding | Embedding        | 5.3 M
# 1 | lstm      | LSTM             | 252 K
# 2 | fc        | Linear           | 17.1 K
# 3 | loss_fn   | CrossEntropyLoss | 0
# -----------------------------------------------
# 5.6 M     Trainable params
# 0         Non-trainable params
# 5.6 M     Total params
# 22.385    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:148: UserWarning: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.test(ckpt_path='best')` to use the best model or `.test(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
#   rank_zero_warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at /content/lightning_logs/version_0/checkpoints/epoch=6-step=6797.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at /content/lightning_logs/version_0/checkpoints/epoch=6-step=6797.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │    0.2563086748123169     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.2563086748123169}]

# %%
from sklearn.metrics import classification_report

# define idx_to_tag
idx_to_tag = {idx: tag for tag, idx in tag_to_idx.items()}

# define device
device = torch.device('cpu')

# Create a dataloader for the test set
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Set the model to evaluation mode
model.eval()

y_true = []
y_pred = []

with torch.no_grad():
    for x, y in test_loader:
        # Move the data to the device
        x = x.to(device)
        y = y.to(device)

        # Forward pass
        y_hat = model(x)

        # Compute the predicted tags
        y_pred += [idx_to_tag[i] for i in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

        # Compute the true tags
        y_true += [idx_to_tag[i] for i in y.cpu().numpy().flatten().tolist()]

print(classification_report(y_true, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
#                   <PAD>       1.00      1.00      1.00    339381
# B-AerospaceManufacturer       0.16      0.05      0.08        97
#   B-AnatomicalStructure       0.67      0.58      0.62       532
#               B-ArtWork       0.21      0.01      0.02       455
#                B-Artist       0.47      0.39      0.43      2744
#               B-Athlete       0.37      0.38      0.38      1087
#       B-CarManufacturer       0.64      0.90      0.75        84
#                B-Cleric       0.50      0.59      0.54       240
#              B-Clothing       0.22      0.65      0.33        17
#               B-Disease       0.71      0.66      0.68       554
#                 B-Drink       0.68      0.80      0.74       120
#              B-Facility       0.56      0.47      0.51       894
#                  B-Food       0.45      0.39      0.42       453
#       B-HumanSettlement       0.77      0.67      0.71      6011
#      B-MedicalProcedure       0.71      0.65      0.68       266
#    B-Medication/Vaccine       0.57      0.54      0.55       462
#            B-MusicalGRP       0.49      0.60      0.54       300
#           B-MusicalWork       0.31      0.41      0.35       226
#                   B-ORG       0.73      0.67      0.70      1988
#              B-OtherLOC       0.55      0.73      0.63       172
#              B-OtherPER       0.31      0.30      0.30      1117
#             B-OtherPROD       0.43      0.38      0.41       704
#            B-Politician       0.44      0.33      0.38      1294
#           B-PrivateCorp       0.95      0.81      0.88       127
#            B-PublicCorp       0.65      0.65      0.65       460
#             B-Scientist       0.24      0.31      0.27       255
#              B-Software       0.72      0.63      0.67       812
#             B-SportsGRP       0.77      0.78      0.78       595
#         B-SportsManager       0.35      0.42      0.38       198
#               B-Station       0.72      0.77      0.74       298
#               B-Symptom       0.68      0.78      0.73       105
#               B-Vehicle       0.71      0.70      0.70       199
#            B-VisualWork       0.47      0.37      0.41       923
#           B-WrittenWork       0.60      0.52      0.56      1224
# I-AerospaceManufacturer       0.00      0.00      0.00       114
#   I-AnatomicalStructure       0.67      0.48      0.56        91
#               I-ArtWork       0.12      0.00      0.01       832
#                I-Artist       0.50      0.43      0.46      2893
#               I-Athlete       0.44      0.35      0.39      1165
#       I-CarManufacturer       0.82      0.88      0.85        57
#                I-Cleric       0.67      0.75      0.71       268
#              I-Clothing       0.36      0.57      0.44         7
#               I-Disease       0.80      0.65      0.72       231
#                 I-Drink       1.00      0.95      0.98        21
#              I-Facility       0.72      0.67      0.69       905
#                  I-Food       0.57      0.42      0.48       175
#       I-HumanSettlement       0.89      0.64      0.74      1672
#      I-MedicalProcedure       0.72      0.77      0.74       155
#    I-Medication/Vaccine       0.83      0.62      0.71       175
#            I-MusicalGRP       0.64      0.61      0.62       239
#           I-MusicalWork       0.41      0.50      0.45       304
#                   I-ORG       0.86      0.76      0.81      2941
#              I-OtherLOC       0.68      0.72      0.70       187
#              I-OtherPER       0.32      0.32      0.32      1334
#             I-OtherPROD       0.65      0.49      0.56       458
#            I-Politician       0.49      0.39      0.43      1515
#           I-PrivateCorp       0.97      0.88      0.92        69
#            I-PublicCorp       0.67      0.68      0.67       282
#             I-Scientist       0.34      0.33      0.34       319
#              I-Software       0.68      0.58      0.62       466
#             I-SportsGRP       0.82      0.86      0.84      1268
#         I-SportsManager       0.36      0.48      0.41       202
#               I-Station       0.88      0.83      0.85       538
#               I-Symptom       0.40      0.35      0.38        17
#               I-Vehicle       0.68      0.65      0.67       101
#            I-VisualWork       0.58      0.47      0.52      1546
#           I-WrittenWork       0.69      0.66      0.67      1550
#                       O       0.95      0.98      0.96    209279
#
#                accuracy                           0.96    595770
#               macro avg       0.59      0.57      0.57    595770
#            weighted avg       0.95      0.96      0.95    595770

# %%
# Set the model to evaluation mode
model.eval()

idx_to_word = {idx: word for word, idx in word_to_idx.items()}

y_true = []
y_pred = []

with torch.no_grad():
    for x, y in test_loader:
        # Move the data to the device
        x = x.to(device)
        y = y.to(device)

        # Forward pass
        y_hat = model(x)

        # Get back the sentence
        x_sent = [idx_to_word[i] for i in x.cpu().numpy().flatten().tolist()]

        # Compute the predicted tags
        y_pred += [idx_to_tag[i] for i in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

        # Compute the true tags
        y_true += [idx_to_tag[i] for i in y.cpu().numpy().flatten().tolist()]
        print("Sentence\t:", end = ' ')
        for i in range(len(x_sent)):
          print(x_sent[i], end = ' ')
        print("\nPredicted tags\t:", end = ' ')
        for i in range(len(y_pred)):
          print(y_pred[i], end = ' ')
        break
# Out:
# Sentence	: প্রোপেলারটি একটি ডি হ্যাভিল্যান্ড এয়ারক্রাফ্ট কোম্পানি স্থির পিচ টাইপ ছিল। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> এটি ১৯৫৫ সালে ১৯৫৭ সালে নর্ড এভিয়েশন পরে snias দ্বারা ডিজাইন করা হয়েছিল। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> পাঁচটি f108 চালিত উদাহরণগুলি বোয়িং কোম্পানি থেকে সরাসরি অনুরোধ করা হয়েছিল বাকী অন্যান্য পক্ষ থেকে। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> গ্রিনহিল ১৯৯৫ সালে l'auto-neige bombardier limitée যোগদানের আগে mckinsey & company, inc. এ তাঁর কেরিয়ার শুরু করেছিলেন। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> যদিও ডকটি অ্যাসোসিয়েটেড ব্রিটিশ পোর্টস এর নিয়ন্ত্রণে পড়ে এটি বর্তমানে কেবলমাত্র bae সিস্টেম পিএলসি দ্বারা ব্যবহৃত হয়। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> তিনি বিদেশী অন্যান্য চুক্তির সাথে সিকরস্কি ম্যানুফ্যাকচারিং কোম্পানি এর জন্য অপারেশনস নেতৃত্ব হিসাবে কাজ করতে গিয়েছিলেন। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ২০১৯ সালে লকহিড-মার্টিন যা স্থানীয়ভাবে উত্পাদিত সিকরস্কি ম্যানুফ্যাকচারিং কোম্পানি এর মালিকানাধীন $ ১ মিলিয়ন প্রতিশ্রুতি দেয়। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> নাসার এস arc বায়ুমণ্ডলীয় প্রোবটি পরিচালনা করেছেন যা হিউজ দ্বারা নির্মিত হয়েছিল। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ক্যাপ্রোনি সিএ। ৩৭ হ'ল একটি গ্রাউন্ড অ্যাটাক বিমান যা ১৯১৬ এর কাছাকাছি ক্যাপ্রোনি ভিজোলা দ্বারা ইতালি এ ডিজাইন করা এবং নির্মিত হয়েছিল <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> সুতরাং কনভায়ার দ্বারা গণ উত্পাদন করা হয়েছিল যা তাদের মধ্যে প্রায় ৩০০ টি তৈরি করেছিল। <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted tags	: O O O O O B-ORG O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O B-ORG O O B-ORG O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O B-AerospaceManufacturer I-Vehicle O O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O B-ORG O I-ORG O O O O O B-HumanSettlement O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O B-Scientist I-ORG I-ORG O O O O O O O O I-ORG O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O O B-ORG O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O O O B-ORG O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O I-Athlete O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O O O O O O O O O O O O O B-WrittenWork O B-HumanSettlement O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> O B-OtherPER O O O O O O O O O O O O O <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/DeepLearning/multiconer2023/BN-Bangla/Bangla_fine.pth')

# %%
bangla_model = model.load_state_dict(torch.load('/content/drive/MyDrive/DeepLearning/multiconer2023/BN-Bangla/Bangla_fine.pth'))

def pred_NER(sentence):
    # Split the sentence into words
    words = sentence.split()
    for word in words:
      word = word.lower()

    # Get the index of the words
    X = []
    for word in words:
        if word not in word_to_idx:
            X.append(word_to_idx["<UNK>"])
        else:
            X.append(word_to_idx[word])
    
    # Create a tensor
    X = torch.tensor(X).unsqueeze(0)
    
    # Get the predictions
    y_hat = model(X)
    
    # Get the predictions
    predictions = [idx_to_tag[pred] for pred in y_hat.argmax(-1).cpu().numpy().flatten().tolist()]

    # Give new sentence
    new_sentence = []
    flag = False
    tag = ""
    for word, pred in zip(words, predictions):
        if pred == "O":
            if flag:
                new_sentence[new_sentence.__len__() - 1] = new_sentence[new_sentence.__len__() - 1] + "[" + tag + "]"
                flag = False
                tag = ""
            new_sentence.append(word)
        elif len(pred) == 0:
            new_sentence.append(word)
        elif pred[0] == "B":
            flag = True
            tag = pred[2:]
            new_sentence.append(word)
        else:
            new_sentence.append(word)
    if flag:
        new_sentence[new_sentence.__len__() - 1] = new_sentence[new_sentence.__len__() - 1] + "[" + tag + "]"
        flag = False
        tag = "" 
    
    return " ".join(new_sentence)
print(pred_NER("আমি জিম ভালোবাসি"))
# Out:
# আমি জিম ভালোবাসি[Athlete]
